# %%
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.signal import butter, filtfilt
from os.path import isfile, join
import zipfile
import os
import json
from pathlib import Path

# %%
import analyze

# %% [markdown]
# ## Load the data

# %%
path = Path('../data/Timo')
onlyfiles = [f for f in os.listdir(path) if '.Identifier' not in f]

# Use all zips
zip_files = {}
for filename in onlyfiles:
    name = filename.removesuffix('.zip')
    parts = name.split()
    if len(parts) >= 3:
        key = f"{parts[0]}_{parts[1]}"
        zip_files[key] = filename

print(zip_files)
# Out:
# {'base_2025-06-11': 'base 2025-06-11 15-08-29.zip', '200ml_2025-06-07': '200ml 2025-06-07 12-52-34.zip', '230ml_2025-06-09': '230ml 2025-06-09 11-42-04.zip', 'base_2025-06-09': 'base 2025-06-09 11-04-21.zip', '150ml_2025-06-12': '150ml 2025-06-12 17-30-26.zip', '230ml_2025-06-11': '230ml 2025-06-11 15-48-34.zip', 'base_2025-06-13': 'base 2025-06-13 17-44-09.zip', 'base_2025-06-06': 'base 2025-06-06 15-45-11.zip', '470ml_2025-06-08': '470ml 2025-06-08 15-38-54.zip', 'base_2025-06-12': 'base 2025-06-12 16-47-24.zip', 'base_2025-06-07': 'base 2025-06-07 12-17-44.zip', '85ml_2025-06-13': '85ml 2025-06-13 18-16-35.zip', 'base_2025-06-08': 'base 2025-06-08 15-05-01.zip', 'base_2025-06-10': 'base 2025-06-10 20-20-33.zip', '230ml_2025-06-06': '230ml 2025-06-06 16-22-45.zip', '230ml_2025-06-10': '230ml 2025-06-10 20-56-58.zip'}

# %%
# Or select specific ones:
# zip_files = {
#     'base_2025-06-06': 'base 2025-06-06 15-45-11.zip',
#     'base_2025-06-07': 'base 2025-06-07 12-17-44.zip', 
#     '200ml_2025-06-07': '200ml 2025-06-07 12-52-34.zip',
#     '230ml_2025-06-06': '230ml 2025-06-06 16-22-45.zip'
# }
# data_path = "/Users/shavindra/Documents/Personal/MLQS/MLQS/data/Timo"
analyzer = analyze.CaffeineAnalyzer(data_path=path, zip_files=zip_files)
analyzer.extract_and_load_data()
analyzer.explore_data_structure()
# Out:
# Loading base_2025-06-11 from base 2025-06-11 15-08-29.zip
#   Files in base 2025-06-11 15-08-29.zip:
#     - Accelerometer.csv
#     - Gyroscope.csv
#     - Linear Acceleration.csv
#     - meta/device.csv
#     - meta/time.csv
#       Loaded Accelerometer.csv as CSV: shape (12202, 4)
#       Loaded Gyroscope.csv as CSV: shape (12175, 4)
#       Loaded Linear Acceleration.csv as CSV: shape (6087, 4)
#
# Loading 200ml_2025-06-07 from 200ml 2025-06-07 12-52-34.zip
#   Files in 200ml 2025-06-07 12-52-34.zip:
#     - Accelerometer.csv
#     - Gyroscope.csv
#     - Linear Acceleration.csv
#     - meta/device.csv
#     - meta/time.csv
#       Loaded Accelerometer.csv as CSV: shape (22461, 4)
#       Loaded Gyroscope.csv as CSV: shape (22423, 4)
#       Loaded Linear Acceleration.csv as CSV: shape (11211, 4)
#
# Loading 230ml_2025-06-09 from 230ml 2025-06-09 11-42-04.zip
#   Files in 230ml 2025-06-09 11-42-04.zip:
#     - Accelerometer.csv
#     - Gyroscope.csv
#     - Linear Acceleration.csv
#     - meta/device.csv
#     - meta/time.csv
#       Loaded Accelerometer.csv as CSV: shape (12403, 4)
#       Loaded Gyroscope.csv as CSV: shape (12399, 4)
#       Loaded Linear Acceleration.csv as CSV: shape (6196, 4)
#
# Loading base_2025-06-09 from base 2025-06-09 11-04-21.zip
#   Files in base 2025-06-09 11-04-21.zip:
#     - Accelerometer.csv
#     - Gyroscope.csv
#     - Linear Acceleration.csv
#     - meta/device.csv
#     - meta/time.csv
#       Loaded Accelerometer.csv as CSV: shape (16539, 4)
#       Loaded Gyroscope.csv as CSV: shape (16512, 4)
#       Loaded Linear Acceleration.csv as CSV: shape (8256, 4)
#
# Loading 150ml_2025-06-12 from 150ml 2025-06-12 17-30-26.zip
#   Files in 150ml 2025-06-12 17-30-26.zip:
#     - Accelerometer.csv
#     - Gyroscope.csv
#     - Linear Acceleration.csv
#     - meta/device.csv
#       Loaded Accelerometer.csv as CSV: shape (14274, 4)
#       Loaded Gyroscope.csv as CSV: shape (14243, 4)
#       Loaded Linear Acceleration.csv as CSV: shape (7122, 4)
#
# Loading 230ml_2025-06-11 from 230ml 2025-06-11 15-48-34.zip
#   Files in 230ml 2025-06-11 15-48-34.zip:
#     - Accelerometer.csv
#     - Gyroscope.csv
#     - Linear Acceleration.csv
#     - meta/device.csv
#     - meta/time.csv
#       Loaded Accelerometer.csv as CSV: shape (18607, 4)
#       Loaded Gyroscope.csv as CSV: shape (18573, 4)
#       Loaded Linear Acceleration.csv as CSV: shape (9287, 4)
#
# Loading base_2025-06-13 from base 2025-06-13 17-44-09.zip
#   Files in base 2025-06-13 17-44-09.zip:
#     - Accelerometer.csv
#     - Gyroscope.csv
#     - Linear Acceleration.csv
#     - meta/device.csv
#     - meta/time.csv
#       Loaded Accelerometer.csv as CSV: shape (16208, 4)
#       Loaded Gyroscope.csv as CSV: shape (16201, 4)
#       Loaded Linear Acceleration.csv as CSV: shape (8096, 4)
#
# Loading base_2025-06-06 from base 2025-06-06 15-45-11.zip
#   Files in base 2025-06-06 15-45-11.zip:
#     - Accelerometer.csv
#     - Gyroscope.csv
#     - Linear Acceleration.csv
#     - meta/device.csv
#     - meta/time.csv
#       Loaded Accelerometer.csv as CSV: shape (14506, 4)
#       Loaded Gyroscope.csv as CSV: shape (14471, 4)
#       Loaded Linear Acceleration.csv as CSV: shape (7236, 4)
#
# Loading 470ml_2025-06-08 from 470ml 2025-06-08 15-38-54.zip
#   Files in 470ml 2025-06-08 15-38-54.zip:
#     - Accelerometer.csv
#     - Gyroscope.csv
#     - Linear Acceleration.csv
#     - meta/device.csv
#     - meta/time.csv
#       Loaded Accelerometer.csv as CSV: shape (20483, 4)
#       Loaded Gyroscope.csv as CSV: shape (20450, 4)
#       Loaded Linear Acceleration.csv as CSV: shape (10225, 4)
#
# Loading base_2025-06-12 from base 2025-06-12 16-47-24.zip
#   Files in base 2025-06-12 16-47-24.zip:
#     - Accelerometer.csv
#     - Gyroscope.csv
#     - Linear Acceleration.csv
#     - meta/device.csv
#     - meta/time.csv
#       Loaded Accelerometer.csv as CSV: shape (15395, 4)
#       Loaded Gyroscope.csv as CSV: shape (15391, 4)
#       Loaded Linear Acceleration.csv as CSV: shape (7690, 4)
#
# Loading base_2025-06-07 from base 2025-06-07 12-17-44.zip
#   Files in base 2025-06-07 12-17-44.zip:
#     - Accelerometer.csv
#     - Gyroscope.csv
#     - Linear Acceleration.csv
#     - meta/device.csv
#     - meta/time.csv
#       Loaded Accelerometer.csv as CSV: shape (16356, 4)
#       Loaded Gyroscope.csv as CSV: shape (16322, 4)
#       Loaded Linear Acceleration.csv as CSV: shape (8161, 4)
#
# Loading 85ml_2025-06-13 from 85ml 2025-06-13 18-16-35.zip
#   Files in 85ml 2025-06-13 18-16-35.zip:
#     - Accelerometer.csv
#     - Gyroscope.csv
#     - Linear Acceleration.csv
#     - meta/device.csv
#     - meta/time.csv
#       Loaded Accelerometer.csv as CSV: shape (14796, 4)
#       Loaded Gyroscope.csv as CSV: shape (14775, 4)
#       Loaded Linear Acceleration.csv as CSV: shape (7382, 4)
#
# Loading base_2025-06-08 from base 2025-06-08 15-05-01.zip
#   Files in base 2025-06-08 15-05-01.zip:
#     - Accelerometer.csv
#     - Gyroscope.csv
#     - Linear Acceleration.csv
#     - meta/device.csv
#     - meta/time.csv
#       Loaded Accelerometer.csv as CSV: shape (18097, 4)
#       Loaded Gyroscope.csv as CSV: shape (18092, 4)
#       Loaded Linear Acceleration.csv as CSV: shape (9041, 4)
#
# Loading base_2025-06-10 from base 2025-06-10 20-20-33.zip
#   Files in base 2025-06-10 20-20-33.zip:
#     - Accelerometer.csv
#     - Gyroscope.csv
#     - Linear Acceleration.csv
#     - meta/device.csv
#     - meta/time.csv
#       Loaded Accelerometer.csv as CSV: shape (13786, 4)
#       Loaded Gyroscope.csv as CSV: shape (13753, 4)
#       Loaded Linear Acceleration.csv as CSV: shape (6876, 4)
#
# Loading 230ml_2025-06-06 from 230ml 2025-06-06 16-22-45.zip
#   Files in 230ml 2025-06-06 16-22-45.zip:
#     - Accelerometer.csv
#     - Gyroscope.csv
#     - Linear Acceleration.csv
#     - meta/device.csv
#     - meta/time.csv
#       Loaded Accelerometer.csv as CSV: shape (14831, 4)
#       Loaded Gyroscope.csv as CSV: shape (14803, 4)
#       Loaded Linear Acceleration.csv as CSV: shape (7401, 4)
#
# Loading 230ml_2025-06-10 from 230ml 2025-06-10 20-56-58.zip
#   Files in 230ml 2025-06-10 20-56-58.zip:
#     - Accelerometer.csv
#     - Gyroscope.csv
#     - Linear Acceleration.csv
#     - meta/device.csv
#     - meta/time.csv
#       Loaded Accelerometer.csv as CSV: shape (15910, 4)
#       Loaded Gyroscope.csv as CSV: shape (15872, 4)
#       Loaded Linear Acceleration.csv as CSV: shape (7936, 4)
#
# Data loading summary:
# Baseline sessions: 8
# Caffeine sessions: 8
# Total sessions: 16
#
# ============================================================
# DATA STRUCTURE ANALYSIS
# ============================================================
#
# --- BASE_2025-06-11 ---
#
# File: Accelerometer.csv
#   Type: DataFrame
#   Shape: (12202, 4)
#   Columns: ['Time_s', 'Acceleration_x_m/s^2', 'Acceleration_y_m/s^2', 'Acceleration_z_m/s^2']
#   Accelerometer columns: ['Acceleration_x_m/s^2', 'Acceleration_y_m/s^2', 'Acceleration_z_m/s^2']
#   Gyroscope columns: []
#   Linear acceleration columns: []
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  Acceleration_z_m/s^2
# 0.023073              0.658924              1.036391             10.034002
# 0.025462              0.651745              1.007677             10.136894
# 0.027851              0.797707              0.959821             10.194322
#   Numeric columns summary:
#              Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  \
# count  12202.000000          12202.000000          12202.000000
# mean      14.577690              0.254654             -0.207574
# std        8.404067              0.324531              0.413538
# min        0.023073             -2.398206             -0.953241
# 25%        7.300449              0.115454             -0.376271
# 50%       14.577698              0.254237             -0.292223
# 75%       21.854935              0.393021             -0.182154
# max       29.132153              5.121538              2.784049
#
#        Acceleration_z_m/s^2
# count          12202.000000
# mean              10.000807
# std                0.346297
# min                7.290332
# 25%                9.803992
# 50%               10.005289
# 75%               10.218250
# max               11.855838
#
# File: Gyroscope.csv
#   Type: DataFrame
#   Shape: (12175, 4)
#   Columns: ['Time_s', 'Gyroscope_x_rad/s', 'Gyroscope_y_rad/s', 'Gyroscope_z_rad/s']
#   Accelerometer columns: []
#   Gyroscope columns: ['Gyroscope_x_rad/s', 'Gyroscope_y_rad/s', 'Gyroscope_z_rad/s']
#   Linear acceleration columns: []
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
# 0.087081          -0.162714           0.364218          -0.120108
# 0.089467          -0.169586           0.345892          -0.117054
# 0.091853          -0.178902           0.336119          -0.111556
#   Numeric columns summary:
#              Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
# count  12175.000000       12175.000000       12175.000000       12175.000000
# mean      14.609368           0.006813          -0.001797           0.000380
# std        8.385472           0.105901           0.150341           0.100278
# min        0.087081          -0.319702          -0.991863          -0.719960
# 25%        7.348231          -0.054900          -0.084144          -0.026648
# 50%       14.609376          -0.000687          -0.004734          -0.004047
# 75%       21.870509           0.055358           0.078952           0.017944
# max       29.131623           0.705834           0.901840           1.020955
#
# File: Linear Acceleration.csv
#   Type: DataFrame
#   Shape: (6087, 4)
#   Columns: ['Time_s', 'Linear_Acceleration_x_m/s^2', 'Linear_Acceleration_y_m/s^2', 'Linear_Acceleration_z_m/s^2']
#   Accelerometer columns: ['Linear_Acceleration_x_m/s^2', 'Linear_Acceleration_y_m/s^2', 'Linear_Acceleration_z_m/s^2']
#   Gyroscope columns: []
#   Linear acceleration columns: ['Linear_Acceleration_x_m/s^2', 'Linear_Acceleration_y_m/s^2', 'Linear_Acceleration_z_m/s^2']
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  Linear_Acceleration_z_m/s^2
# 0.088265                    -0.588600                     0.055030                    -0.339494
# 0.093037                    -0.513531                    -0.045110                    -0.150194
# 0.097809                    -0.415715                    -0.041248                    -0.110139
#   Numeric columns summary:
#             Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  \
# count  6087.000000                  6087.000000                  6087.000000
# mean     14.608166                    -0.001784                     0.000079
# std       8.385127                     0.269586                     0.164526
# min       0.088265                    -1.824009                    -1.040663
# 25%       7.348223                    -0.122239                    -0.060499
# 50%      14.608174                    -0.009251                    -0.000958
# 75%      21.868114                     0.115782                     0.059523
# max      29.128035                     4.673919                     1.528782
#
#        Linear_Acceleration_z_m/s^2
# count                  6087.000000
# mean                     -0.002854
# std                       0.344608
# min                      -2.663270
# 25%                      -0.201380
# 50%                      -0.003642
# 75%                       0.214408
# max                       1.929927
#
# --- 200ML_2025-06-07 ---
#
# File: Accelerometer.csv
#   Type: DataFrame
#   Shape: (22461, 4)
#   Columns: ['Time_s', 'Acceleration_x_m/s^2', 'Acceleration_y_m/s^2', 'Acceleration_z_m/s^2']
#   Accelerometer columns: ['Acceleration_x_m/s^2', 'Acceleration_y_m/s^2', 'Acceleration_z_m/s^2']
#   Gyroscope columns: []
#   Linear acceleration columns: []
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  Acceleration_z_m/s^2
# 0.029908             -0.176770              0.483350             10.452746
# 0.032342             -0.131007              0.500100             10.414461
# 0.034775             -0.095115              0.526421             10.347463
#   Numeric columns summary:
#              Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  \
# count  22461.000000          22461.000000          22461.000000
# mean      26.819081              0.536815             -0.811966
# std       15.466735              0.522356              0.584777
# min        0.029908             -1.560419             -3.234797
# 25%       13.425403              0.225524             -1.135095
# 50%       26.819097              0.496212             -0.874278
# 75%       40.212771              0.804886             -0.610768
# max       53.606439              8.140383              5.053641
#
#        Acceleration_z_m/s^2
# count          22461.000000
# mean               9.930712
# std                0.528857
# min                4.946563
# 25%                9.619745
# 50%                9.940384
# 75%               10.254143
# max               13.225131
#
# File: Gyroscope.csv
#   Type: DataFrame
#   Shape: (22423, 4)
#   Columns: ['Time_s', 'Gyroscope_x_rad/s', 'Gyroscope_y_rad/s', 'Gyroscope_z_rad/s']
#   Accelerometer columns: []
#   Gyroscope columns: ['Gyroscope_x_rad/s', 'Gyroscope_y_rad/s', 'Gyroscope_z_rad/s']
#   Linear acceleration columns: []
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
# 0.121604          -0.202496           0.327567           0.023289
# 0.124037          -0.208070           0.341005           0.028786
# 0.126470          -0.209979           0.333675           0.030619
#   Numeric columns summary:
#              Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
# count  22423.000000       22423.000000       22423.000000       22423.000000
# mean      26.863874           0.005700          -0.003490           0.008823
# std       15.440565           0.111656           0.171653           0.096090
# min        0.121604          -0.557016          -1.046229          -0.265642
# 25%       13.492856          -0.055434          -0.103080          -0.026190
# 50%       26.863888          -0.001222          -0.002902           0.001298
# 75%       40.234901           0.055434           0.096667           0.028175
# max       53.605909           0.947119           0.866334           1.257200
#
# File: Linear Acceleration.csv
#   Type: DataFrame
#   Shape: (11211, 4)
#   Columns: ['Time_s', 'Linear_Acceleration_x_m/s^2', 'Linear_Acceleration_y_m/s^2', 'Linear_Acceleration_z_m/s^2']
#   Accelerometer columns: ['Linear_Acceleration_x_m/s^2', 'Linear_Acceleration_y_m/s^2', 'Linear_Acceleration_z_m/s^2']
#   Gyroscope columns: []
#   Linear acceleration columns: ['Linear_Acceleration_x_m/s^2', 'Linear_Acceleration_y_m/s^2', 'Linear_Acceleration_z_m/s^2']
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  Linear_Acceleration_z_m/s^2
# 0.122835                    -0.099617                    -0.054924                    -0.329295
# 0.127701                    -0.132548                    -0.145168                     0.062313
# 0.132501                    -0.237570                    -0.000834                     0.691394
#   Numeric columns summary:
#              Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  \
# count  11211.000000                 11211.000000                 11211.000000
# mean      26.862672                     0.017135                     0.001234
# std       15.440221                     0.328608                     0.204704
# min        0.122835                    -1.802844                    -2.606901
# 25%       13.492846                    -0.172936                    -0.078281
# 50%       26.862687                     0.012198                     0.001984
# 75%       40.232507                     0.203124                     0.082044
# max       53.602322                     4.965217                     3.417909
#
#        Linear_Acceleration_z_m/s^2
# count                 11211.000000
# mean                     -0.004068
# std                       0.520893
# min                      -3.218436
# 25%                      -0.314162
# 50%                       0.001580
# 75%                       0.310898
# max                       3.271357
#
# --- 230ML_2025-06-09 ---
#
# File: Accelerometer.csv
#   Type: DataFrame
#   Shape: (12403, 4)
#   Columns: ['Time_s', 'Acceleration_x_m/s^2', 'Acceleration_y_m/s^2', 'Acceleration_z_m/s^2']
#   Accelerometer columns: ['Acceleration_x_m/s^2', 'Acceleration_y_m/s^2', 'Acceleration_z_m/s^2']
#   Gyroscope columns: []
#   Linear acceleration columns: []
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  Acceleration_z_m/s^2
# 0.019924              0.587139              2.602195              9.248559
# 0.022309              0.515354              2.654837              9.243773
# 0.024694              0.443570              2.604588              9.305986
#   Numeric columns summary:
#              Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  \
# count  12403.000000          12403.000000          12403.000000
# mean      14.813295              0.413711             -0.029601
# std        8.541983              0.542855              0.608874
# min        0.019924             -2.407778             -2.722434
# 25%        7.416617              0.108275             -0.261117
# 50%       14.813300              0.410070             -0.122333
# 75%       22.209975              0.706780              0.014058
# max       29.606649              6.531508              4.584349
#
#        Acceleration_z_m/s^2
# count          12403.000000
# mean               9.982588
# std                0.550015
# min                6.598208
# 25%                9.655638
# 50%                9.988539
# 75%               10.301999
# max               13.069597
#
# File: Gyroscope.csv
#   Type: DataFrame
#   Shape: (12399, 4)
#   Columns: ['Time_s', 'Gyroscope_x_rad/s', 'Gyroscope_y_rad/s', 'Gyroscope_z_rad/s']
#   Accelerometer columns: []
#   Gyroscope columns: ['Gyroscope_x_rad/s', 'Gyroscope_y_rad/s', 'Gyroscope_z_rad/s']
#   Linear acceleration columns: []
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
# 0.028936          -0.383459           0.545945           0.065361
# 0.031322          -0.387812           0.550221           0.058641
# 0.033708          -0.393462           0.541058           0.049479
#   Numeric columns summary:
#              Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
# count  12399.000000       12399.000000       12399.000000       12399.000000
# mean      14.817536           0.001848          -0.000370           0.010508
# std        8.539229           0.126426           0.199103           0.173891
# min        0.028936          -0.685065          -0.830981          -0.451416
# 25%        7.423244          -0.053831          -0.119955          -0.036040
# 50%       14.817541           0.002214          -0.001374          -0.003054
# 75%       22.211830           0.058947           0.110411           0.029321
# max       29.606119           0.958038           0.974149           1.740380
#
# File: Linear Acceleration.csv
#   Type: DataFrame
#   Shape: (6196, 4)
#   Columns: ['Time_s', 'Linear_Acceleration_x_m/s^2', 'Linear_Acceleration_y_m/s^2', 'Linear_Acceleration_z_m/s^2']
#   Accelerometer columns: ['Linear_Acceleration_x_m/s^2', 'Linear_Acceleration_y_m/s^2', 'Linear_Acceleration_z_m/s^2']
#   Gyroscope columns: []
#   Linear acceleration columns: ['Linear_Acceleration_x_m/s^2', 'Linear_Acceleration_y_m/s^2', 'Linear_Acceleration_z_m/s^2']
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  Linear_Acceleration_z_m/s^2
# 0.044434                     0.000000                     0.000000                     0.000000
# 0.049205                     0.029604                    -0.019819                     0.140162
# 0.053977                    -0.183001                     0.062668                     0.464220
#   Numeric columns summary:
#             Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  \
# count  6196.000000                  6196.000000                  6196.000000
# mean     14.823491                     0.008107                    -0.021441
# std       8.534752                     0.467396                     0.317983
# min       0.044434                    -2.175527                    -3.129473
# 25%       7.433970                    -0.254668                    -0.091687
# 50%      14.823496                    -0.009496                    -0.003772
# 75%      22.213014                     0.230983                     0.077533
# max      29.602532                     5.877311                     2.832977
#
#        Linear_Acceleration_z_m/s^2
# count                  6196.000000
# mean                     -0.016867
# std                       0.545708
# min                      -3.408686
# 25%                      -0.339002
# 50%                      -0.010281
# 75%                       0.303529
# max                       3.030840
#
# --- BASE_2025-06-09 ---
#
# File: Accelerometer.csv
#   Type: DataFrame
#   Shape: (16539, 4)
#   Columns: ['Time_s', 'Acceleration_x_m/s^2', 'Acceleration_y_m/s^2', 'Acceleration_z_m/s^2']
#   Accelerometer columns: ['Acceleration_x_m/s^2', 'Acceleration_y_m/s^2', 'Acceleration_z_m/s^2']
#   Gyroscope columns: []
#   Linear acceleration columns: []
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  Acceleration_z_m/s^2
# 0.026461              0.711566              1.287638             10.151251
# 0.028848              0.711566              1.234996             10.175179
# 0.031235              0.701994              1.309173             10.220643
#   Numeric columns summary:
#              Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  \
# count  16539.000000          16539.000000          16539.000000
# mean      19.751425              1.148788             -0.711345
# std       11.389166              0.641732              0.541128
# min        0.026461             -1.186840             -2.080858
# 25%        9.889020              0.711566             -0.898206
# 50%       19.751440              1.001396             -0.780658
# 75%       29.613836              1.621436             -0.689731
# max       39.476228              5.504688              3.585944
#
#        Acceleration_z_m/s^2
# count          16539.000000
# mean               9.868948
# std                0.462464
# min                5.712565
# 25%                9.665209
# 50%                9.868599
# 75%               10.084252
# max               13.720744
#
# File: Gyroscope.csv
#   Type: DataFrame
#   Shape: (16512, 4)
#   Columns: ['Time_s', 'Gyroscope_x_rad/s', 'Gyroscope_y_rad/s', 'Gyroscope_z_rad/s']
#   Accelerometer columns: []
#   Gyroscope columns: ['Gyroscope_x_rad/s', 'Gyroscope_y_rad/s', 'Gyroscope_z_rad/s']
#   Linear acceleration columns: []
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
# 0.090445          -0.178520           0.454012           0.040698
# 0.092830          -0.171648           0.412475           0.035811
# 0.095216          -0.161722           0.347114           0.016875
#   Numeric columns summary:
#              Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
# count  16512.000000       16512.000000       16512.000000       16512.000000
# mean      19.783098           0.003049          -0.001406           0.009725
# std       11.370573           0.104961           0.136850           0.146553
# min        0.090445          -0.664525          -0.594813          -0.758901
# 25%        9.936794          -0.029626          -0.078036          -0.019776
# 50%       19.783113          -0.000305          -0.005956          -0.002062
# 75%       29.629408           0.030237           0.068568           0.016264
# max       39.475698           1.101281           0.999499           1.459161
#
# File: Linear Acceleration.csv
#   Type: DataFrame
#   Shape: (8256, 4)
#   Columns: ['Time_s', 'Linear_Acceleration_x_m/s^2', 'Linear_Acceleration_y_m/s^2', 'Linear_Acceleration_z_m/s^2']
#   Accelerometer columns: ['Linear_Acceleration_x_m/s^2', 'Linear_Acceleration_y_m/s^2', 'Linear_Acceleration_z_m/s^2']
#   Gyroscope columns: []
#   Linear acceleration columns: ['Linear_Acceleration_x_m/s^2', 'Linear_Acceleration_y_m/s^2', 'Linear_Acceleration_z_m/s^2']
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  Linear_Acceleration_z_m/s^2
# 0.089243                     0.009764                     0.017212                     0.736806
# 0.094014                    -0.068113                    -0.074448                     0.891050
# 0.098785                     0.339800                    -0.336626                     1.294848
#   Numeric columns summary:
#             Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  \
# count  8256.000000                  8256.000000                  8256.000000
# mean     19.780703                     0.000345                    -0.014320
# std      11.370917                     0.294634                     0.208180
# min       0.089243                    -2.078407                    -2.057866
# 25%       9.934996                    -0.126504                    -0.053429
# 50%      19.780718                    -0.000809                     0.001492
# 75%      29.626417                     0.118586                     0.051471
# max      39.472111                     3.726717                     1.621546
#
#        Linear_Acceleration_z_m/s^2
# count                  8256.000000
# mean                     -0.018312
# std                       0.455339
# min                      -4.102894
# 25%                      -0.196053
# 50%                       0.000549
# 75%                       0.189928
# max                       3.582793
#
# --- 150ML_2025-06-12 ---
#
# File: Accelerometer.csv
#   Type: DataFrame
#   Shape: (14274, 4)
#   Columns: ['Time_s', 'Acceleration_x_m/s^2', 'Acceleration_y_m/s^2', 'Acceleration_z_m/s^2']
#   Accelerometer columns: ['Acceleration_x_m/s^2', 'Acceleration_y_m/s^2', 'Acceleration_z_m/s^2']
#   Gyroscope columns: []
#   Linear acceleration columns: []
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  Acceleration_z_m/s^2
# 0.024516             -3.868297              5.067998              8.449057
# 0.026954             -3.779763              4.986642              8.496913
# 0.029391             -3.672086              4.902894              8.563912
#   Numeric columns summary:
#              Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  \
# count  14274.000000          14274.000000          14274.000000
# mean      17.053033              0.103439             -0.684538
# std        9.831184              0.816146              0.977104
# min        0.024516             -3.868297             -5.875277
# 25%        8.539887             -0.260519             -0.998704
# 50%       17.053047              0.058026             -0.842872
# 75%       25.566192              0.352343             -0.665803
# max       34.079329             18.286549              7.002595
#
#        Acceleration_z_m/s^2
# count          14274.000000
# mean               9.941323
# std                0.840483
# min                2.624029
# 25%                9.581460
# 50%                9.961919
# 75%               10.347463
# max               20.431416
#
# File: Gyroscope.csv
#   Type: DataFrame
#   Shape: (14243, 4)
#   Columns: ['Time_s', 'Gyroscope_x_rad/s', 'Gyroscope_y_rad/s', 'Gyroscope_z_rad/s']
#   Accelerometer columns: []
#   Gyroscope columns: ['Gyroscope_x_rad/s', 'Gyroscope_y_rad/s', 'Gyroscope_z_rad/s']
#   Linear acceleration columns: []
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
# 0.099328          -0.455997          -1.230475          -0.518533
# 0.101762          -0.516395          -1.253077          -0.542356
# 0.104195          -0.584352          -1.261018          -0.569233
#   Numeric columns summary:
#              Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
# count  14243.000000       14243.000000       14243.000000       14243.000000
# mean      17.089486          -0.000687          -0.018219           0.016605
# std        9.809827           0.372637           0.337126           0.243131
# min        0.099328          -5.721653          -2.582357          -2.203326
# 25%        8.594828          -0.071545          -0.148054          -0.042072
# 50%       17.089497           0.005116          -0.000840          -0.000534
# 75%       25.584152           0.081090           0.127438           0.045584
# max       34.078799           2.633897           2.170188           2.617022
#
# File: Linear Acceleration.csv
#   Type: DataFrame
#   Shape: (7122, 4)
#   Columns: ['Time_s', 'Linear_Acceleration_x_m/s^2', 'Linear_Acceleration_y_m/s^2', 'Linear_Acceleration_z_m/s^2']
#   Accelerometer columns: ['Linear_Acceleration_x_m/s^2', 'Linear_Acceleration_y_m/s^2', 'Linear_Acceleration_z_m/s^2']
#   Gyroscope columns: []
#   Linear acceleration columns: ['Linear_Acceleration_x_m/s^2', 'Linear_Acceleration_y_m/s^2', 'Linear_Acceleration_z_m/s^2']
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  Linear_Acceleration_z_m/s^2
# 0.098126                    -0.598055                     1.088812                    -0.747117
# 0.102993                    -0.583368                     1.044132                    -0.963207
# 0.107860                    -0.549683                     0.916963                    -1.193056
#   Numeric columns summary:
#             Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  \
# count  7122.000000                  7122.000000                  7122.000000
# mean     17.088285                    -0.007227                    -0.017124
# std       9.810861                     0.571936                     0.489232
# min       0.098126                    -3.840804                    -4.746441
# 25%       8.593626                    -0.255476                    -0.087260
# 50%      17.088295                    -0.006854                    -0.005260
# 75%      25.582950                     0.230356                     0.080842
# max      34.077598                    14.891655                     5.154270
#
#        Linear_Acceleration_z_m/s^2
# count                  7122.000000
# mean                     -0.018997
# std                       0.823667
# min                      -6.987424
# 25%                      -0.383497
# 50%                      -0.017924
# 75%                       0.365580
# max                      10.271247
#
# --- 230ML_2025-06-11 ---
#
# File: Accelerometer.csv
#   Type: DataFrame
#   Shape: (18607, 4)
#   Columns: ['Time_s', 'Acceleration_x_m/s^2', 'Acceleration_y_m/s^2', 'Acceleration_z_m/s^2']
#   Accelerometer columns: ['Acceleration_x_m/s^2', 'Acceleration_y_m/s^2', 'Acceleration_z_m/s^2']
#   Gyroscope columns: []
#   Linear acceleration columns: []
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  Acceleration_z_m/s^2
# 0.026173              0.046062              2.164009             10.053145
# 0.028606              0.046062              2.161616             10.089038
# 0.031040              0.105882              2.185544             10.151251
#   Numeric columns summary:
#              Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  \
# count  18607.000000          18607.000000          18607.000000
# mean      22.217336             -0.039819             -0.581130
# std       12.812659              0.524640              0.800615
# min        0.026173             -3.451647             -2.327319
# 25%       11.122144             -0.334696             -0.862014
# 50%       22.217335             -0.097508             -0.739980
# 75%       33.312527              0.168096             -0.524626
# max       44.407729              8.221739              6.226723
#
#        Acceleration_z_m/s^2
# count          18607.000000
# mean               9.962844
# std                0.553396
# min                2.178964
# 25%                9.667602
# 50%                9.976275
# 75%               10.287642
# max               14.814862
#
# File: Gyroscope.csv
#   Type: DataFrame
#   Shape: (18573, 4)
#   Columns: ['Time_s', 'Gyroscope_x_rad/s', 'Gyroscope_y_rad/s', 'Gyroscope_z_rad/s']
#   Accelerometer columns: []
#   Gyroscope columns: ['Gyroscope_x_rad/s', 'Gyroscope_y_rad/s', 'Gyroscope_z_rad/s']
#   Linear acceleration columns: []
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
# 0.107522          -0.044897          -0.537087          -0.111938
# 0.109907          -0.040545          -0.557245          -0.179742
# 0.112292          -0.036193          -0.552359          -0.234718
#   Numeric columns summary:
#              Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
# count  18573.000000       18573.000000       18573.000000       18573.000000
# mean      22.257357           0.007540          -0.002975           0.007011
# std       12.789247           0.152713           0.227751           0.111144
# min        0.107522          -1.975862          -1.282321          -0.747295
# 25%       11.182439          -0.066124          -0.145534          -0.030084
# 50%       22.257355           0.000611          -0.002596          -0.001374
# 75%       33.332272           0.069102           0.139197           0.026725
# max       44.407199           1.069746           1.292476           1.305228
#
# File: Linear Acceleration.csv
#   Type: DataFrame
#   Shape: (9287, 4)
#   Columns: ['Time_s', 'Linear_Acceleration_x_m/s^2', 'Linear_Acceleration_y_m/s^2', 'Linear_Acceleration_z_m/s^2']
#   Accelerometer columns: ['Linear_Acceleration_x_m/s^2', 'Linear_Acceleration_y_m/s^2', 'Linear_Acceleration_z_m/s^2']
#   Gyroscope columns: []
#   Linear acceleration columns: ['Linear_Acceleration_x_m/s^2', 'Linear_Acceleration_y_m/s^2', 'Linear_Acceleration_z_m/s^2']
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  Linear_Acceleration_z_m/s^2
# 0.106320                     1.750470                    -0.341627                    -0.024207
# 0.111090                     1.678621                     0.179138                    -0.806521
# 0.115861                     1.250998                     0.323732                    -1.319580
#   Numeric columns summary:
#             Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  \
# count  9287.000000                  9287.000000                  9287.000000
# mean     22.256155                    -0.001524                    -0.009330
# std      12.790280                     0.345918                     0.288064
# min       0.106320                    -3.585039                    -3.536883
# 25%      11.181238                    -0.159430                    -0.061086
# 50%      22.256153                    -0.002995                    -0.002293
# 75%      33.331070                     0.155874                     0.058535
# max      44.405997                     6.452843                     2.705991
#
#        Linear_Acceleration_z_m/s^2
# count                  9287.000000
# mean                     -0.012982
# std                       0.535507
# min                      -5.331364
# 25%                      -0.315793
# 50%                      -0.004694
# 75%                       0.302719
# max                       5.039218
#
# --- BASE_2025-06-13 ---
#
# File: Accelerometer.csv
#   Type: DataFrame
#   Shape: (16208, 4)
#   Columns: ['Time_s', 'Acceleration_x_m/s^2', 'Acceleration_y_m/s^2', 'Acceleration_z_m/s^2']
#   Accelerometer columns: ['Acceleration_x_m/s^2', 'Acceleration_y_m/s^2', 'Acceleration_z_m/s^2']
#   Gyroscope columns: []
#   Linear acceleration columns: []
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  Acceleration_z_m/s^2
# 0.022376              0.910170              1.785644             10.354641
# 0.024762              0.891027              1.754537             10.376176
# 0.027148              0.891027              1.761716             10.426426
#   Numeric columns summary:
#              Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  \
# count  16208.000000          16208.000000          16208.000000
# mean      19.357622              0.124407             -0.568027
# std       11.164216              0.425671              0.595701
# min        0.022376             -3.736692             -2.906681
# 25%        9.690029             -0.044865             -0.895813
# 50%       19.357643              0.113061             -0.550947
# 75%       29.025226              0.259023             -0.376271
# max       38.692781              3.720839              3.832704
#
#        Acceleration_z_m/s^2
# count          16208.000000
# mean               9.980664
# std                0.436782
# min                5.877670
# 25%                9.768100
# 50%                9.981061
# 75%               10.199107
# max               13.941183
#
# File: Gyroscope.csv
#   Type: DataFrame
#   Shape: (16201, 4)
#   Columns: ['Time_s', 'Gyroscope_x_rad/s', 'Gyroscope_y_rad/s', 'Gyroscope_z_rad/s']
#   Accelerometer columns: []
#   Gyroscope columns: ['Gyroscope_x_rad/s', 'Gyroscope_y_rad/s', 'Gyroscope_z_rad/s']
#   Linear acceleration columns: []
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
# 0.038548          -0.133623           0.148283          -0.034207
# 0.040934          -0.135455           0.104302          -0.061696
# 0.043321          -0.129881           0.090253          -0.086740
#   Numeric columns summary:
#              Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
# count  16201.000000       16201.000000       16201.000000       16201.000000
# mean      19.365443           0.001334          -0.004803           0.001464
# std       11.159394           0.119659           0.175871           0.156730
# min        0.038548          -1.372956          -1.560333          -0.807540
# 25%        9.702026          -0.050089          -0.080785          -0.026266
# 50%       19.365464          -0.001527          -0.003818          -0.005498
# 75%       29.028871           0.046424           0.076814           0.015271
# max       38.692251           0.794789           1.442669           1.963339
#
# File: Linear Acceleration.csv
#   Type: DataFrame
#   Shape: (8096, 4)
#   Columns: ['Time_s', 'Linear_Acceleration_x_m/s^2', 'Linear_Acceleration_y_m/s^2', 'Linear_Acceleration_z_m/s^2']
#   Accelerometer columns: ['Linear_Acceleration_x_m/s^2', 'Linear_Acceleration_y_m/s^2', 'Linear_Acceleration_z_m/s^2']
#   Gyroscope columns: []
#   Linear acceleration columns: ['Linear_Acceleration_x_m/s^2', 'Linear_Acceleration_y_m/s^2', 'Linear_Acceleration_z_m/s^2']
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  Linear_Acceleration_z_m/s^2
# 0.056435                     0.000000                     0.000000                     0.000000
# 0.061207                    -0.149111                    -0.021344                    -0.139519
# 0.065979                    -0.259560                     0.052847                    -0.152312
#   Numeric columns summary:
#             Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  \
# count  8096.000000                  8096.000000                  8096.000000
# mean     19.371399                    -0.002953                     0.002999
# std      11.153539                     0.330705                     0.296671
# min       0.056435                    -3.023636                    -2.691777
# 25%       9.713947                    -0.128783                    -0.046313
# 50%      19.371420                    -0.013128                     0.000896
# 75%      29.028862                     0.105006                     0.052009
# max      38.686277                     3.350203                     3.093609
#
#        Linear_Acceleration_z_m/s^2
# count                  8096.000000
# mean                     -0.005892
# std                       0.433334
# min                      -3.969691
# 25%                      -0.217991
# 50%                      -0.006526
# 75%                       0.210966
# max                       3.765811
#
# --- BASE_2025-06-06 ---
#
# File: Accelerometer.csv
#   Type: DataFrame
#   Shape: (14506, 4)
#   Columns: ['Time_s', 'Acceleration_x_m/s^2', 'Acceleration_y_m/s^2', 'Acceleration_z_m/s^2']
#   Accelerometer columns: ['Acceleration_x_m/s^2', 'Acceleration_y_m/s^2', 'Acceleration_z_m/s^2']
#   Gyroscope columns: []
#   Linear acceleration columns: []
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  Acceleration_z_m/s^2
# 0.026569              0.484247              0.478565             10.409676
# 0.029005              0.465105              0.476172             10.476675
# 0.031442              0.419641              0.485743             10.541281
#   Numeric columns summary:
#              Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  \
# count  14506.000000          14506.000000          14506.000000
# mean      17.329891              1.202858              0.042714
# std        9.990064              0.603414              0.800285
# min        0.026569             -1.467099             -1.558924
# 25%        8.679145              0.821635             -0.333201
# 50%       17.329901              1.221536             -0.110369
# 75%       25.980646              1.626222              0.059521
# max       34.631381             10.661520              4.024129
#
#        Acceleration_z_m/s^2
# count          14506.000000
# mean               9.867930
# std                0.491314
# min                3.854837
# 25%                9.589236
# 50%                9.868599
# 75%               10.160224
# max               14.022539
#
# File: Gyroscope.csv
#   Type: DataFrame
#   Shape: (14471, 4)
#   Columns: ['Time_s', 'Gyroscope_x_rad/s', 'Gyroscope_y_rad/s', 'Gyroscope_z_rad/s']
#   Accelerometer columns: []
#   Gyroscope columns: ['Gyroscope_x_rad/s', 'Gyroscope_y_rad/s', 'Gyroscope_z_rad/s']
#   Linear acceleration columns: []
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
# 0.111058           0.059023           0.082235          -0.083381
# 0.113491           0.050929           0.131103          -0.082159
# 0.115924           0.048410           0.175695          -0.079716
#   Numeric columns summary:
#              Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
# count  14471.000000       14471.000000       14471.000000       14471.000000
# mean      17.371111           0.012967           0.001739           0.037364
# std        9.965957           0.112525           0.171386           0.092696
# min        0.111058          -0.439428          -1.214059          -0.289847
# 25%        8.741237          -0.042530          -0.099492           0.002749
# 50%       17.371119           0.004200           0.003436           0.028404
# 75%       26.000990           0.055282           0.103004           0.052838
# max       34.630851           1.068983           1.134114           0.936734
#
# File: Linear Acceleration.csv
#   Type: DataFrame
#   Shape: (7236, 4)
#   Columns: ['Time_s', 'Linear_Acceleration_x_m/s^2', 'Linear_Acceleration_y_m/s^2', 'Linear_Acceleration_z_m/s^2']
#   Accelerometer columns: ['Linear_Acceleration_x_m/s^2', 'Linear_Acceleration_y_m/s^2', 'Linear_Acceleration_z_m/s^2']
#   Gyroscope columns: []
#   Linear acceleration columns: ['Linear_Acceleration_x_m/s^2', 'Linear_Acceleration_y_m/s^2', 'Linear_Acceleration_z_m/s^2']
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  Linear_Acceleration_z_m/s^2
# 0.109856                     0.277802                    -0.447070                    -0.411475
# 0.114723                     0.179781                    -0.426015                    -0.392758
# 0.119589                     0.048719                    -0.354287                    -0.262329
#   Numeric columns summary:
#             Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  \
# count  7236.000000                  7236.000000                  7236.000000
# mean     17.369909                     0.040348                    -0.002072
# std       9.966990                     0.386031                     0.205254
# min       0.109856                    -2.086293                    -2.121664
# 25%       8.740035                    -0.173632                    -0.071175
# 50%      17.369917                     0.037788                     0.009503
# 75%      25.999788                     0.243885                     0.083444
# max      34.629649                     8.715405                     2.006695
#
#        Linear_Acceleration_z_m/s^2
# count                  7236.000000
# mean                     -0.004921
# std                       0.468049
# min                      -5.389732
# 25%                      -0.273680
# 50%                      -0.006543
# 75%                       0.270265
# max                       4.039153
#
# --- 470ML_2025-06-08 ---
#
# File: Accelerometer.csv
#   Type: DataFrame
#   Shape: (20483, 4)
#   Columns: ['Time_s', 'Acceleration_x_m/s^2', 'Acceleration_y_m/s^2', 'Acceleration_z_m/s^2']
#   Accelerometer columns: ['Acceleration_x_m/s^2', 'Acceleration_y_m/s^2', 'Acceleration_z_m/s^2']
#   Gyroscope columns: []
#   Linear acceleration columns: []
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  Acceleration_z_m/s^2
# 0.025488              1.724328              1.699502              9.368199
# 0.027876              1.664507              1.675574              9.341879
# 0.030264              1.585544              1.670788              9.317950
#   Numeric columns summary:
#              Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  \
# count  20483.000000          20483.000000          20483.000000
# mean      24.456357              0.598378             -0.477790
# std       14.106104              0.642762              0.350893
# min        0.025488             -2.589931             -1.343271
# 25%       12.241013              0.158524             -0.672981
# 50%       24.456376              0.615853             -0.507877
# 75%       36.671710              1.068395             -0.337986
# max       48.887021              4.542176              1.890928
#
#        Acceleration_z_m/s^2
# count          20483.000000
# mean               9.956292
# std                0.708999
# min                7.060322
# 25%                9.495318
# 50%                9.957133
# 75%               10.426426
# max               12.384951
#
# File: Gyroscope.csv
#   Type: DataFrame
#   Shape: (20450, 4)
#   Columns: ['Time_s', 'Gyroscope_x_rad/s', 'Gyroscope_y_rad/s', 'Gyroscope_z_rad/s']
#   Accelerometer columns: []
#   Gyroscope columns: ['Gyroscope_x_rad/s', 'Gyroscope_y_rad/s', 'Gyroscope_z_rad/s']
#   Linear acceleration columns: []
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
# 0.103810          -0.106746           0.056580           0.058336
# 0.106195          -0.133546           0.077349           0.058947
# 0.108581          -0.154697           0.101782           0.057725
#   Numeric columns summary:
#              Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
# ...
# 0.058442                    -0.093346                     0.016243                    -0.127625
# 0.063214                    -0.165996                     0.011038                    -0.240023
#   Numeric columns summary:
#             Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  \
# count  9041.000000                  9041.000000                  9041.000000
# mean     21.622251                     0.031619                     0.016749
# std      12.454686                     0.295224                     0.149901
# min       0.053670                    -1.298831                    -1.063882
# 25%      10.837975                    -0.145102                    -0.061044
# 50%      21.622233                     0.032737                     0.016243
# 75%      32.406531                     0.204142                     0.091389
# max      43.190838                     3.720870                     1.205781
#
#        Linear_Acceleration_z_m/s^2
# count                  9041.000000
# mean                     -0.002146
# std                       0.418810
# min                      -4.799047
# 25%                      -0.263219
# 50%                      -0.000987
# 75%                       0.254595
# max                       2.341160
#
# --- BASE_2025-06-10 ---
#
# File: Accelerometer.csv
#   Type: DataFrame
#   Shape: (13786, 4)
#   Columns: ['Time_s', 'Acceleration_x_m/s^2', 'Acceleration_y_m/s^2', 'Acceleration_z_m/s^2']
#   Accelerometer columns: ['Acceleration_x_m/s^2', 'Acceleration_y_m/s^2', 'Acceleration_z_m/s^2']
#   Gyroscope columns: []
#   Linear acceleration columns: []
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  Acceleration_z_m/s^2
# 0.031504             -0.013759              2.331506             10.172787
# 0.033891              0.046062              2.381756             10.225429
# 0.036278              0.089133              2.381756             10.261321
#   Numeric columns summary:
#              Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  \
# count  13786.000000          13786.000000          13786.000000
# mean      16.473492              0.096228             -0.323318
# std        9.493742              0.483401              0.749361
# min        0.031504             -2.199602             -2.624328
# 25%        8.252569             -0.123829             -0.550349
# 50%       16.473496              0.072383             -0.404985
# 75%       24.694419              0.263809             -0.227617
# max       32.915339              4.247559              4.965107
#
#        Acceleration_z_m/s^2
# count          13786.000000
# mean               9.979835
# std                0.544689
# min                5.829813
# 25%                9.744172
# 50%               10.002896
# 75%               10.244571
# max               16.052549
#
# File: Gyroscope.csv
#   Type: DataFrame
#   Shape: (13753, 4)
#   Columns: ['Time_s', 'Gyroscope_x_rad/s', 'Gyroscope_y_rad/s', 'Gyroscope_z_rad/s']
#   Accelerometer columns: []
#   Gyroscope columns: ['Gyroscope_x_rad/s', 'Gyroscope_y_rad/s', 'Gyroscope_z_rad/s']
#   Linear acceleration columns: []
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
# 0.109813          -0.329934           0.228686          -0.144771
# 0.112198          -0.314968           0.188370          -0.168594
# 0.114584          -0.301835           0.151719          -0.194860
#   Numeric columns summary:
#              Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
# count  13753.000000       13753.000000       13753.000000       13753.000000
# mean      16.512322           0.004862          -0.004451           0.004287
# std        9.471017           0.149797           0.210247           0.164461
# min        0.109813          -1.587897          -1.970364          -1.125868
# 25%        8.311080          -0.048257          -0.100561          -0.028710
# 50%       16.512326           0.001603          -0.001603          -0.002443
# 75%       24.713569           0.052075           0.093689           0.024434
# max       32.914809           1.302555           1.657534           1.802610
#
# File: Linear Acceleration.csv
#   Type: DataFrame
#   Shape: (6876, 4)
#   Columns: ['Time_s', 'Linear_Acceleration_x_m/s^2', 'Linear_Acceleration_y_m/s^2', 'Linear_Acceleration_z_m/s^2']
#   Accelerometer columns: ['Linear_Acceleration_x_m/s^2', 'Linear_Acceleration_y_m/s^2', 'Linear_Acceleration_z_m/s^2']
#   Gyroscope columns: []
#   Linear acceleration columns: ['Linear_Acceleration_x_m/s^2', 'Linear_Acceleration_y_m/s^2', 'Linear_Acceleration_z_m/s^2']
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  Linear_Acceleration_z_m/s^2
# 0.108611                     0.733973                     0.425267                     0.798477
# 0.113382                     0.579358                     0.437963                     0.565559
# 0.118153                     0.484223                     0.539038                     0.372924
#   Numeric columns summary:
#             Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  \
# count  6876.000000                  6876.000000                  6876.000000
# mean     16.508735                     0.005205                    -0.015358
# std       9.470673                     0.340986                     0.391579
# min       0.108611                    -2.124528                    -3.532417
# 25%       8.308685                    -0.159804                    -0.053161
# 50%      16.508738                     0.001434                     0.001422
# 75%      24.708789                     0.152697                     0.055041
# max      32.908836                     3.702351                     3.461065
#
#        Linear_Acceleration_z_m/s^2
# count                  6876.000000
# mean                     -0.011333
# std                       0.536334
# min                      -3.881035
# 25%                      -0.248489
# 50%                       0.004411
# 75%                       0.240084
# max                       6.244983
#
# --- 230ML_2025-06-06 ---
#
# File: Accelerometer.csv
#   Type: DataFrame
#   Shape: (14831, 4)
#   Columns: ['Time_s', 'Acceleration_x_m/s^2', 'Acceleration_y_m/s^2', 'Acceleration_z_m/s^2']
#   Accelerometer columns: ['Acceleration_x_m/s^2', 'Acceleration_y_m/s^2', 'Acceleration_z_m/s^2']
#   Gyroscope columns: []
#   Linear acceleration columns: []
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  Acceleration_z_m/s^2
# 0.025827              0.771386              0.466600             10.447961
# 0.028261              0.668495              0.457029             10.505388
# 0.030695              0.579960              0.370888             10.534102
#   Numeric columns summary:
#              Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  \
# count  14831.000000          14831.000000          14831.000000
# mean      17.714164              0.520408             -0.414974
# std       10.213207              0.539983              0.679374
# min        0.025827             -2.544468             -1.585245
# 25%        8.870165              0.189631             -0.725623
# 50%       17.714168              0.515354             -0.527019
# 75%       26.558166              0.852742             -0.297009
# max       35.402164              3.306881              3.890131
#
#        Acceleration_z_m/s^2
# count          14831.000000
# mean               9.950300
# std                0.638193
# min                6.818647
# 25%                9.550353
# 50%                9.954741
# 75%               10.363016
# max               12.327523
#
# File: Gyroscope.csv
#   Type: DataFrame
#   Shape: (14803, 4)
#   Columns: ['Time_s', 'Gyroscope_x_rad/s', 'Gyroscope_y_rad/s', 'Gyroscope_z_rad/s']
#   Accelerometer columns: []
#   Gyroscope columns: ['Gyroscope_x_rad/s', 'Gyroscope_y_rad/s', 'Gyroscope_z_rad/s']
#   Linear acceleration columns: []
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
# 0.092414          -0.084908          -0.428509          -0.104760
# 0.094800          -0.104226          -0.397967          -0.104149
# 0.097185          -0.127896          -0.360018          -0.101706
#   Numeric columns summary:
#              Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
# count  14803.000000       14803.000000       14803.000000       14803.000000
# mean      17.747031           0.011917           0.004366           0.032727
# std       10.193925           0.122178           0.247547           0.110620
# min        0.092414          -0.448209          -1.121210          -0.541516
# 25%        8.919729          -0.055053          -0.148054          -0.007025
# 50%       17.747034           0.003512           0.007712           0.023518
# 75%       26.574334           0.065208           0.150650           0.057725
# max       35.401634           1.110139           1.134725           1.338748
#
# File: Linear Acceleration.csv
#   Type: DataFrame
#   Shape: (7401, 4)
#   Columns: ['Time_s', 'Linear_Acceleration_x_m/s^2', 'Linear_Acceleration_y_m/s^2', 'Linear_Acceleration_z_m/s^2']
#   Accelerometer columns: ['Linear_Acceleration_x_m/s^2', 'Linear_Acceleration_y_m/s^2', 'Linear_Acceleration_z_m/s^2']
#   Gyroscope columns: []
#   Linear acceleration columns: ['Linear_Acceleration_x_m/s^2', 'Linear_Acceleration_y_m/s^2', 'Linear_Acceleration_z_m/s^2']
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  Linear_Acceleration_z_m/s^2
# 0.093598                    -0.429390                    -0.012210                    -0.231919
# 0.098369                    -0.355073                     0.082857                    -0.619518
# 0.103140                    -0.315672                     0.210070                    -0.769521
#   Numeric columns summary:
#             Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  \
# count  7401.000000                  7401.000000                  7401.000000
# mean     17.745829                     0.067973                     0.000481
# std      10.193581                     0.449548                     0.231987
# min       0.093598                    -2.518908                    -2.286959
# 25%       8.919720                    -0.202589                    -0.103719
# 50%      17.745832                     0.070021                    -0.001302
# 75%      26.571939                     0.338352                     0.102981
# max      35.398047                     2.059100                     1.696481
#
#        Linear_Acceleration_z_m/s^2
# count                  7401.000000
# mean                     -0.010018
# std                       0.627661
# min                      -2.619175
# 25%                      -0.403277
# 50%                      -0.004783
# 75%                       0.391695
# max                       2.427429
#
# --- 230ML_2025-06-10 ---
#
# File: Accelerometer.csv
#   Type: DataFrame
#   Shape: (15910, 4)
#   Columns: ['Time_s', 'Acceleration_x_m/s^2', 'Acceleration_y_m/s^2', 'Acceleration_z_m/s^2']
#   Accelerometer columns: ['Acceleration_x_m/s^2', 'Acceleration_y_m/s^2', 'Acceleration_z_m/s^2']
#   Gyroscope columns: []
#   Linear acceleration columns: []
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  Acceleration_z_m/s^2
# 0.028741             -0.780060              1.780858             10.019646
# 0.031177             -0.784846              1.795215             10.101002
# 0.033613             -0.789631              1.811965             10.158429
#   Numeric columns summary:
#              Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  \
# count  15910.000000          15910.000000          15910.000000
# mean      19.006935              0.248591             -0.588808
# std       10.957035              0.374115              0.466762
# min        0.028741             -2.580360             -1.448854
# 25%        9.518777              0.055633             -0.845265
# 50%       19.006955              0.263809             -0.617946
# 75%       28.495109              0.472283             -0.448056
# max       37.983256              5.320142              3.143272
#
#        Acceleration_z_m/s^2
# count          15910.000000
# mean               9.982083
# std                0.444566
# min                6.799505
# 25%                9.722636
# 50%                9.988539
# 75%               10.244571
# max               12.545270
#
# File: Gyroscope.csv
#   Type: DataFrame
#   Shape: (15872, 4)
#   Columns: ['Time_s', 'Gyroscope_x_rad/s', 'Gyroscope_y_rad/s', 'Gyroscope_z_rad/s']
#   Accelerometer columns: []
#   Gyroscope columns: ['Gyroscope_x_rad/s', 'Gyroscope_y_rad/s', 'Gyroscope_z_rad/s']
#   Linear acceleration columns: []
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
# 0.120533          -0.108731          -0.306416          -0.109953
# 0.122966          -0.109953          -0.311914          -0.109953
# 0.125400          -0.119955          -0.312525          -0.106898
#   Numeric columns summary:
#              Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
# count  15872.000000       15872.000000       15872.000000       15872.000000
# mean      19.051734          -0.000375          -0.001575          -0.008680
# std       10.930862           0.118315           0.215318           0.085831
# min        0.120533          -0.817772          -1.190312          -0.618865
# 25%        9.586237          -0.064444          -0.120719          -0.033597
# 50%       19.051752          -0.000305          -0.001603          -0.005498
# 75%       28.517242           0.062612           0.113847           0.021380
# max       37.982726           0.651469           1.534754           0.618788
#
# File: Linear Acceleration.csv
#   Type: DataFrame
#   Shape: (7936, 4)
#   Columns: ['Time_s', 'Linear_Acceleration_x_m/s^2', 'Linear_Acceleration_y_m/s^2', 'Linear_Acceleration_z_m/s^2']
#   Accelerometer columns: ['Linear_Acceleration_x_m/s^2', 'Linear_Acceleration_y_m/s^2', 'Linear_Acceleration_z_m/s^2']
#   Gyroscope columns: []
#   Linear acceleration columns: ['Linear_Acceleration_x_m/s^2', 'Linear_Acceleration_y_m/s^2', 'Linear_Acceleration_z_m/s^2']
#   Time columns: ['Time_s']
#   Sample data (first 3 rows):
#   Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  Linear_Acceleration_z_m/s^2
# 0.121764                     0.194096                     0.013138                     0.358062
# 0.126617                     0.225344                     0.071457                     0.294611
# 0.131389                     0.286775                     0.169831                     0.033933
#   Numeric columns summary:
#             Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  \
# count  7936.000000                  7936.000000                  7936.000000
# mean     19.051725                    -0.003816                    -0.011852
# std      10.931206                     0.261711                     0.147826
# min       0.121764                    -1.944645                    -1.399941
# 25%       9.586825                    -0.140177                    -0.056441
# 50%      19.051743                    -0.006835                    -0.000633
# 75%      28.516637                     0.129578                     0.052512
# max      37.981525                     5.114332                     2.100237
#
#        Linear_Acceleration_z_m/s^2
# count                  7936.000000
# mean                     -0.006082
# std                       0.442302
# min                      -2.787563
# 25%                      -0.265188
# 50%                      -0.002147
# 75%                       0.259706
# max                       2.502696

# %%
analyzer.all_data
# Out:
# {'base_2025-06-11': {'Accelerometer.csv':           Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  \
#   0       0.023073              0.658924              1.036391
#   1       0.025462              0.651745              1.007677
#   2       0.027851              0.797707              0.959821
#   3       0.030240              0.900599              0.957428
#   4       0.032629              0.864706              0.964607
#   ...          ...                   ...                   ...
#   12197  29.122610              1.515853              2.657230
#   12198  29.124995              1.525724              2.688336
#   12199  29.127381              1.592723              2.669194
#   12200  29.129767              1.671686              2.702693
#   12201  29.132153              1.702792              2.724229
#
#          Acceleration_z_m/s^2
#   0                 10.034002
#   1                 10.136894
#   2                 10.194322
#   3                 10.223036
#   4                 10.246963
#   ...                     ...
#   12197              9.665209
#   12198              9.440284
#   12199              9.329915
#   12200              9.258130
#   12201              9.227023
#
#   [12202 rows x 4 columns],
#   'Gyroscope.csv':           Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
#   0       0.087081          -0.162714           0.364218          -0.120108
#   1       0.089467          -0.169586           0.345892          -0.117054
#   2       0.091853          -0.178902           0.336119          -0.111556
#   3       0.094239          -0.186996           0.326956          -0.106669
#   4       0.096625          -0.193257           0.325734          -0.103615
#   ...          ...                ...                ...                ...
#   12170  29.122080           0.619857          -0.244186          -0.035200
#   12171  29.124465           0.625508          -0.238078          -0.041919
#   12172  29.126851           0.624820          -0.224028          -0.048639
#   12173  29.129237           0.621155          -0.209979          -0.053525
#   12174  29.131623           0.609931          -0.197762          -0.057191
#
#   [12175 rows x 4 columns],
#   'Linear Acceleration.csv':          Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  \
#   0      0.088265                    -0.588600                     0.055030
#   1      0.093037                    -0.513531                    -0.045110
#   2      0.097809                    -0.415715                    -0.041248
#   3      0.102580                    -0.242048                    -0.046225
#   4      0.107352                    -0.086650                    -0.045182
#   ...         ...                          ...                          ...
#   6082  29.108949                     0.281492                    -0.049475
#   6083  29.113720                     0.450447                    -0.024116
#   6084  29.118492                     0.474864                    -0.071753
#   6085  29.123263                     0.460104                    -0.045457
#   6086  29.128035                     0.478928                    -0.045551
#
#         Linear_Acceleration_z_m/s^2
#   0                       -0.339494
#   1                       -0.150194
#   2                       -0.110139
#   3                       -0.225855
#   4                       -0.325607
#   ...                           ...
#   6082                     1.120968
#   6083                     0.980377
#   6084                     0.757119
#   6085                     0.179531
#   6086                    -0.237153
#
#   [6087 rows x 4 columns]},
#  '200ml_2025-06-07': {'Accelerometer.csv':           Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  \
#   0       0.029908             -0.176770              0.483350
#   1       0.032342             -0.131007              0.500100
#   2       0.034775             -0.095115              0.526421
#   3       0.037209             -0.073579              0.492921
#   4       0.039642             -0.061615              0.538385
#   ...          ...                   ...                   ...
#   22456  53.596898              3.211168              2.424827
#   22457  53.599283              3.278167              2.432005
#   22458  53.601669              3.373880              2.479861
#   22459  53.604054              3.431308              2.451148
#   22460  53.606439              3.443272              2.604588
#
#          Acceleration_z_m/s^2
#   0                 10.452746
#   1                 10.414461
#   2                 10.347463
#   3                 10.287642
#   4                 10.232607
#   ...                     ...
#   22456              7.963015
#   22457              7.723433
#   22458              7.567900
#   22459              7.467401
#   22460              7.445866
#
#   [22461 rows x 4 columns],
#   'Gyroscope.csv':           Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
#   0       0.121604          -0.202496           0.327567           0.023289
#   1       0.124037          -0.208070           0.341005           0.028786
#   2       0.126470          -0.209979           0.333675           0.030619
#   3       0.128903          -0.208757           0.295192           0.026954
#   4       0.131318          -0.195624           0.251822           0.025732
#   ...          ...                ...                ...                ...
#   22418  53.596368           0.482264          -0.406061           0.032451
#   22419  53.598753           0.449889          -0.355971           0.037949
#   22420  53.601139           0.416216          -0.298552           0.041003
#   22421  53.603524           0.380711          -0.232580           0.040392
#   22422  53.605909           0.337111          -0.163554           0.039171
#
#   [22423 rows x 4 columns],
#   'Linear Acceleration.csv':           Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  \
#   0       0.122835                    -0.099617                    -0.054924
#   1       0.127701                    -0.132548                    -0.145168
#   2       0.132501                    -0.237570                    -0.000834
#   3       0.137272                    -0.232019                    -0.086888
#   4       0.142043                    -0.154873                    -0.213832
#   ...          ...                          ...                          ...
#   11206  53.583240                    -0.129466                     0.256966
#   11207  53.588010                    -0.043588                     0.060985
#   11208  53.592781                    -0.111544                    -0.057218
#   11209  53.597552                    -0.167789                    -0.226184
#   11210  53.602322                    -0.111430                    -0.309411
#
#          Linear_Acceleration_z_m/s^2
#   0                        -0.329295
#   1                         0.062313
#   2                         0.691394
#   3                         0.840500
#   4                         0.943684
#   ...                            ...
#   11206                     0.636406
#   11207                     0.338733
#   11208                    -0.141427
#   11209                    -0.755641
#   11210                    -1.213930
#
#   [11211 rows x 4 columns]},
#  '230ml_2025-06-09': {'Accelerometer.csv':           Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  \
#   0       0.019924              0.587139              2.602195
#   1       0.022309              0.515354              2.654837
#   2       0.024694              0.443570              2.604588
#   3       0.027081              0.441177              2.429612
#   4       0.029466              0.520140              2.271686
#   ...          ...                   ...                   ...
#   12398  29.597107              0.620638              2.197509
#   12399  29.599492              0.589532              2.204687
#   12400  29.601878              0.556032              2.235794
#   12401  29.604264              0.532104              2.242972
#   12402  29.606649              0.477069              2.199901
#
#          Acceleration_z_m/s^2
#   0                  9.248559
#   1                  9.243773
#   2                  9.305986
#   3                  9.368199
#   4                  9.612567
#   ...                     ...
#   12398              9.521640
#   12399              9.543175
#   12400              9.581460
#   12401              9.646067
#   12402              9.691530
#
#   [12403 rows x 4 columns],
#   'Gyroscope.csv':           Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
#   0       0.028936          -0.383459           0.545945           0.065361
#   1       0.031322          -0.387812           0.550221           0.058641
#   2       0.033708          -0.393462           0.541058           0.049479
#   3       0.036093          -0.389721           0.531895           0.042759
#   4       0.038479          -0.389033           0.506240           0.037873
#   ...          ...                ...                ...                ...
#   12394  29.596577           0.150497          -0.086359           0.060474
#   12395  29.598962           0.140571          -0.066201           0.065361
#   12396  29.601348           0.131179          -0.043523           0.069637
#   12397  29.603734           0.125605          -0.020311           0.073913
#   12398  29.606119           0.115603           0.001680           0.076967
#
#   [12399 rows x 4 columns],
#   'Linear Acceleration.csv':          Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  \
#   0      0.044434                     0.000000                     0.000000
#   1      0.049205                     0.029604                    -0.019819
#   2      0.053977                    -0.183001                     0.062668
#   3      0.058748                    -0.006178                    -0.092517
#   4      0.063519                     0.174294                    -0.399352
#   ...         ...                          ...                          ...
#   6191  29.583447                     0.350111                    -0.401922
#   6192  29.588218                     0.314449                    -0.284446
#   6193  29.592989                     0.261282                    -0.233162
#   6194  29.597760                     0.193284                    -0.300489
#   6195  29.602532                     0.140479                    -0.319090
#
#         Linear_Acceleration_z_m/s^2
#   0                        0.000000
#   1                        0.140162
#   2                        0.464220
#   3                        0.113321
#   4                        0.015841
#   ...                           ...
#   6191                    -0.061202
#   6192                    -0.204445
#   6193                    -0.277265
#   6194                    -0.260662
#   6195                    -0.245575
#
#   [6196 rows x 4 columns]},
#  'base_2025-06-09': {'Accelerometer.csv':           Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  \
#   0       0.026461              0.711566              1.287638
#   1       0.028848              0.711566              1.234996
#   2       0.031235              0.701994              1.309173
#   3       0.033622              0.843171              1.242174
#   4       0.036009              0.895813              1.278066
#   ...          ...                   ...                   ...
#   16534  39.466687              2.028216              1.313959
#   16535  39.469072              2.047359              1.325923
#   16536  39.471457              2.049752              1.301995
#   16537  39.473843              2.025823              1.342673
#   16538  39.476228              1.997110              1.333101
#
#          Acceleration_z_m/s^2
#   0                 10.151251
#   1                 10.175179
#   2                 10.220643
#   3                 10.278070
#   4                 10.282856
#   ...                     ...
#   16534              9.490533
#   16535              9.497711
#   16536              9.526425
#   16537              9.588638
#   16538              9.629316
#
#   [16539 rows x 4 columns],
#   'Gyroscope.csv':           Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
#   0       0.090445          -0.178520           0.454012           0.040698
#   1       0.092830          -0.171648           0.412475           0.035811
#   2       0.095216          -0.161722           0.347114           0.016875
#   3       0.097601          -0.149276           0.270758          -0.003894
#   4       0.099987          -0.139884           0.193180          -0.016722
#   ...          ...                ...                ...                ...
#   16507  39.466156           0.003436           0.123544           0.049860
#   16508  39.468542          -0.005956           0.134539           0.044363
#   16509  39.470927          -0.013439           0.144313           0.038254
#   16510  39.473313          -0.018402           0.153475           0.033978
#   16511  39.475698          -0.023976           0.157751           0.027259
#
#   [16512 rows x 4 columns],
#   'Linear Acceleration.csv':          Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  \
#   0      0.089243                     0.009764                     0.017212
#   1      0.094014                    -0.068113                    -0.074448
#   2      0.098785                     0.339800                    -0.336626
#   3      0.103556                     0.112489                     0.354288
#   4      0.108326                     0.080798                     0.175768
#   ...         ...                          ...                          ...
#   8251  39.453028                     0.034706                    -0.270222
#   8252  39.457798                     0.104330                    -0.222816
#   8253  39.462569                     0.170470                    -0.165547
#   8254  39.467340                     0.216284                    -0.172018
#   8255  39.472111                     0.250845                    -0.133926
#
#         Linear_Acceleration_z_m/s^2
#   0                        0.736806
#   1                        0.891050
#   2                        1.294848
#   3                        1.009530
#   4                        0.348495
#   ...                           ...
#   8251                    -0.021260
#   8252                    -0.137657
#   8253                    -0.325945
#   8254                    -0.346886
#   8255                    -0.348927
#
#   [8256 rows x 4 columns]},
#  '150ml_2025-06-12': {'Accelerometer.csv':           Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  \
#   0       0.024516             -3.868297              5.067998
#   1       0.026954             -3.779763              4.986642
#   2       0.029391             -3.672086              4.902894
#   3       0.031827             -3.530909              4.783252
#   4       0.034265             -3.387040              4.680062
#   ...          ...                   ...                   ...
#   14269  34.069786              1.156930              2.829513
#   14270  34.072172              1.209572              2.910869
#   14271  34.074558              1.276571              2.999403
#   14272  34.076944              1.305285              3.016153
#   14273  34.079329              1.348356              3.085844
#
#          Acceleration_z_m/s^2
#   0                  8.449057
#   1                  8.496913
#   2                  8.563912
#   3                  8.650054
#   4                  8.750552
#   ...                     ...
#   14269              9.255737
#   14270              9.152845
#   14271              9.097811
#   14272              9.100204
#   14273              9.145667
#
#   [14274 rows x 4 columns],
#   'Gyroscope.csv':           Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
#   0       0.099328          -0.455997          -1.230475          -0.518533
#   1       0.101762          -0.516395          -1.253077          -0.542356
#   2       0.104195          -0.584352          -1.261018          -0.569233
#   3       0.106629          -0.647269          -1.259796          -0.598554
#   4       0.109062          -0.710797          -1.249412          -0.625431
#   ...          ...                ...                ...                ...
#   14238  34.069256           0.417590          -0.407664           0.042225
#   14239  34.071642           0.417590          -0.388728           0.051388
#   14240  34.074028           0.413238          -0.366737           0.060550
#   14241  34.076414           0.409497          -0.347801           0.072767
#   14242  34.078799           0.405755          -0.329476           0.085595
#
#   [14243 rows x 4 columns],
#   'Linear Acceleration.csv':          Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  \
#   0      0.098126                    -0.598055                     1.088812
#   1      0.102993                    -0.583368                     1.044132
#   2      0.107860                    -0.549683                     0.916963
#   3      0.112727                    -0.442422                     0.684173
#   4      0.117594                    -0.313645                     0.399690
#   ...         ...                          ...                          ...
#   7117  34.058511                    -0.095270                    -0.077250
#   7118  34.063283                    -0.245256                    -0.093546
#   7119  34.068054                    -0.531868                    -0.348720
#   7120  34.072826                    -0.383826                    -0.241873
#   7121  34.077598                    -0.266443                    -0.114011
#
#         Linear_Acceleration_z_m/s^2
#   0                       -0.747117
#   1                       -0.963207
#   2                       -1.193056
#   3                       -1.394694
#   4                       -1.376985
#   ...                           ...
#   7117                     0.727198
#   7118                     0.594445
#   7119                     0.398926
#   7120                    -0.152488
#   7121                    -0.382693
#
#   [7122 rows x 4 columns]},
#  '230ml_2025-06-11': {'Accelerometer.csv':           Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  \
#   0       0.026173              0.046062              2.164009
#   1       0.028606              0.046062              2.161616
#   2       0.031040              0.105882              2.185544
#   3       0.033472              0.134596              2.152045
#   4       0.035905              0.189631              2.132902
#   ...          ...                   ...                   ...
#   18602  44.398188              1.915754              4.129414
#   18603  44.400573              1.925325              4.122235
#   18604  44.402958              1.937289              4.091128
#   18605  44.405344              1.899004              4.110271
#   18606  44.407729              1.915754              4.103093
#
#          Acceleration_z_m/s^2
#   0                 10.053145
#   1                 10.089038
#   2                 10.151251
#   3                 10.213465
#   4                 10.273285
#   ...                     ...
#   18602              8.123334
#   18603              8.020442
#   18604              7.939086
#   18605              7.943872
#   18606              7.974979
#
#   [18607 rows x 4 columns],
#   'Gyroscope.csv':           Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
#   0       0.107522          -0.044897          -0.537087          -0.111938
#   1       0.109907          -0.040545          -0.557245          -0.179742
#   2       0.112292          -0.036193          -0.552359          -0.234718
#   3       0.114678          -0.046119          -0.538920          -0.278775
#   4       0.117063          -0.059252          -0.529757          -0.316648
#   ...          ...                ...                ...                ...
#   18568  44.397658           0.123926          -0.127209           0.089642
#   18569  44.400043           0.099644          -0.096056           0.090864
#   18570  44.402428           0.075974          -0.060627           0.090253
#   18571  44.404814           0.047341          -0.022143           0.092696
#   18572  44.407199           0.021761           0.016951           0.096361
#
#   [18573 rows x 4 columns],
#   'Linear Acceleration.csv':          Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  \
#   0      0.106320                     1.750470                    -0.341627
#   1      0.111090                     1.678621                     0.179138
#   2      0.115861                     1.250998                     0.323732
#   3      0.120632                     1.194210                     0.139560
#   4      0.125402                     0.976941                     0.040351
#   ...         ...                          ...                          ...
#   9282  44.386915                     0.043096                    -0.247214
#   9283  44.391685                     0.010766                    -0.185611
#   9284  44.396456                    -0.010238                    -0.085122
#   9285  44.401227                     0.026457                    -0.080781
#   9286  44.405997                     0.048327                    -0.110000
#
#         Linear_Acceleration_z_m/s^2
#   0                       -0.024207
#   1                       -0.806521
#   2                       -1.319580
#   3                       -1.340156
#   4                       -1.346917
#   ...                           ...
#   9282                     0.236164
#   9283                    -0.152269
#   9284                    -0.500806
#   9285                    -0.781061
#   9286                    -0.979026
#
#   [9287 rows x 4 columns]},
#  'base_2025-06-13': {'Accelerometer.csv':           Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  \
#   0       0.022376              0.910170              1.785644
#   1       0.024762              0.891027              1.754537
#   2       0.027148              0.891027              1.761716
#   3       0.029534              0.867099              1.670788
#   4       0.031920              0.850349              1.673181
#   ...          ...                   ...                   ...
#   16203  38.683237              1.750649              1.740180
#   16204  38.685623              1.712364              1.756930
#   16205  38.688009              1.695614              1.737787
#   16206  38.690395              1.638186              1.804786
#   16207  38.692781              1.556830              1.797608
#
#          Acceleration_z_m/s^2
#   0                 10.354641
#   1                 10.376176
#   2                 10.426426
#   3                 10.445568
#   4                 10.498210
#   ...                     ...
#   16203              9.806385
#   16204              9.746565
#   16205              9.698709
#   16206              9.691530
#   16207              9.715458
#
#   [16208 rows x 4 columns],
#   'Gyroscope.csv':           Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
#   0       0.038548          -0.133623           0.148283          -0.034207
#   1       0.040934          -0.135455           0.104302          -0.061696
#   2       0.043321          -0.129881           0.090253          -0.086740
#   3       0.045707          -0.118046           0.090253          -0.105677
#   4       0.048093          -0.107433           0.096972          -0.120948
#   ...          ...                ...                ...                ...
#   16196  38.682707           0.234642          -0.092391           0.027488
#   16197  38.685093           0.242125          -0.104608           0.032986
#   16198  38.687479           0.246477          -0.115603           0.037262
#   16199  38.689865           0.251440          -0.125987           0.041538
#   16200  38.692251           0.258923          -0.141869           0.047035
#
#   [16201 rows x 4 columns],
#   'Linear Acceleration.csv':          Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  \
#   0      0.056435                     0.000000                     0.000000
#   1      0.061207                    -0.149111                    -0.021344
#   2      0.065979                    -0.259560                     0.052847
#   3      0.070751                    -0.190323                     0.056716
#   4      0.075523                     0.075953                     0.089854
#   ...         ...                          ...                          ...
#   8091  38.667189                     0.441472                    -0.247571
#   8092  38.671961                     0.373253                    -0.196154
#   8093  38.676733                     0.283066                    -0.179918
#   8094  38.681505                     0.182781                    -0.166342
#   8095  38.686277                     0.089881                    -0.195041
#
#         Linear_Acceleration_z_m/s^2
#   0                        0.000000
#   1                       -0.139519
#   2                       -0.152312
#   3                       -0.267348
#   4                       -0.094041
#   ...                           ...
#   8091                     0.647584
#   8092                     0.355138
#   8093                     0.143350
#   8094                     0.107744
#   8095                     0.116704
#
#   [8096 rows x 4 columns]},
#  'base_2025-06-06': {'Accelerometer.csv':           Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  \
#   0       0.026569              0.484247              0.478565
#   1       0.029005              0.465105              0.476172
#   2       0.031442              0.419641              0.485743
#   3       0.033877              0.503390              0.495314
#   4       0.036313              0.766601              0.533599
#   ...          ...                   ...                   ...
#   14501  34.621838              2.296512              3.463910
#   14502  34.624224              2.313261              3.564409
#   14503  34.626610              2.334797              3.581158
#   14504  34.628995              2.310869              3.641278
#   14505  34.631381              2.274976              3.677170
#
#          Acceleration_z_m/s^2
#   0                 10.409676
#   1                 10.476675
#   2                 10.541281
#   3                 10.582258
#   4                 10.627722
#   ...                     ...
#   14501              8.987741
#   14502              8.733803
#   14503              8.535198
#   14504              8.350951
#   14505              8.123334
#
#   [14506 rows x 4 columns],
#   'Gyroscope.csv':           Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
#   0       0.111058           0.059023           0.082235          -0.083381
#   1       0.113491           0.050929           0.131103          -0.082159
#   2       0.115924           0.048410           0.175695          -0.079716
#   3       0.118358           0.048410           0.212957          -0.077272
#   4       0.120791           0.043447           0.242888          -0.071164
#   ...          ...                ...                ...                ...
#   14466  34.621308           0.356811          -0.407130          -0.014355
#   14467  34.623694           0.345587          -0.394302          -0.018631
#   14468  34.626080           0.327567          -0.372846          -0.023518
#   14469  34.628465           0.310081          -0.344747          -0.025961
#   14470  34.630851           0.285189          -0.307485          -0.023518
#
#   [14471 rows x 4 columns],
#   'Linear Acceleration.csv':          Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  \
#   0      0.109856                     0.277802                    -0.447070
#   1      0.114723                     0.179781                    -0.426015
#   2      0.119589                     0.048719                    -0.354287
#   3      0.124451                    -0.049573                    -0.259456
#   4      0.129223                    -0.141288                    -0.205185
#   ...         ...                          ...                          ...
#   7231  34.610564                     0.102647                    -0.240185
#   7232  34.615335                     0.075600                    -0.239660
#   7233  34.620107                     0.115489                    -0.232225
#   7234  34.624878                     0.117132                    -0.153381
#   7235  34.629649                     0.146428                    -0.022773
#
#         Linear_Acceleration_z_m/s^2
#   0                       -0.411475
#   1                       -0.392758
#   2                       -0.262329
#   3                       -0.094467
#   4                        0.060445
#   ...                           ...
#   7231                     1.240772
#   7232                     1.096261
#   7233                     0.599425
#   7234                     0.084699
#   7235                    -0.381577
#
#   [7236 rows x 4 columns]},
#  '470ml_2025-06-08': {'Accelerometer.csv':           Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  \
#   0       0.025488              1.724328              1.699502
#   1       0.027876              1.664507              1.675574
#   2       0.030264              1.585544              1.670788
#   3       0.032651              1.525724              1.630110
#   4       0.035040              1.472782              1.630110
#   ...          ...                   ...                   ...
#   20478  48.877479              0.546461              1.661217
#   20479  48.879865              0.594317              1.610968
#   20480  48.882250              0.682852              1.555933
#   20481  48.884636              0.754636              1.512862
#   20482  48.887021              0.862313              1.424328
#
#          Acceleration_z_m/s^2
#   0                  9.368199
#   1                  9.341879
#   2                  9.317950
#   3                  9.322736
#   4                  9.351450
#   ...                     ...
#   20478              9.763314
#   20479              9.751350
#   20480              9.705887
#   20481              9.646067
#   20482              9.605389
#
#   [20483 rows x 4 columns],
#   'Gyroscope.csv':           Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
#   0       0.103810          -0.106746           0.056580           0.058336
#   1       0.106195          -0.133546           0.077349           0.058947
#   2       0.108581          -0.154697           0.101782           0.057725
#   3       0.110967          -0.172183           0.135990           0.054060
#   4       0.113352          -0.189592           0.180582           0.051006
#   ...          ...                ...                ...                ...
#   20445  48.876949           0.150574          -0.129118           0.061390
#   20446  48.879335           0.150574          -0.109571           0.069942
#   20447  48.881720           0.151872          -0.084526           0.079105
#   20448  48.884106           0.148741          -0.057649           0.087657
#   20449  48.886491           0.148741          -0.029550           0.093154
#
#   [20450 rows x 4 columns],
#   'Linear Acceleration.csv':           Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  \
#   0       0.102608                     0.403406                     0.111702
#   1       0.107379                     0.539835                     0.094744
#   2       0.112150                     0.675835                     0.056084
#   3       0.116921                     0.733080                     0.009393
#   4       0.121693                     0.785578                    -0.017515
#   ...          ...                          ...                          ...
#   10220  48.863819                    -0.205056                     0.227559
#   10221  48.868591                    -0.106441                     0.216745
#   10222  48.873362                     0.024966                     0.181898
#   10223  48.878133                     0.053527                     0.233289
#   10224  48.882904                     0.145175                     0.172287
#
#          Linear_Acceleration_z_m/s^2
#   0                        -0.983722
#   1                        -1.012669
#   2                        -1.013445
#   3                        -1.109280
#   4                        -1.096145
#   ...                            ...
#   10220                    -0.065045
#   10221                    -0.018193
#   10222                     0.078817
#   10223                    -0.034773
#   10224                    -0.126795
#
#   [10225 rows x 4 columns]},
#  'base_2025-06-12': {'Accelerometer.csv':           Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  \
#   0       0.021551              0.273380              0.380459
#   1       0.023937              0.247059              0.363709
#   2       0.026323              0.259023              0.375673
#   3       0.028709              0.254237              0.363709
#   4       0.031095              0.220738              0.387637
#   ...          ...                   ...                   ...
#   15390  36.742601              2.217548              2.214258
#   15391  36.744987              2.260619              2.197509
#   15392  36.747373              2.320440              2.142473
#   15393  36.749759              2.375475              2.185544
#   15394  36.752145              2.392225              2.147259
#
#          Acceleration_z_m/s^2
#   0                 10.115358
#   1                 10.153644
#   2                 10.156036
#   3                 10.199107
#   4                 10.215858
#   ...                     ...
#   15390              9.329915
#   15391              9.260523
#   15392              9.176774
#   15393              9.167203
#   15394              9.124132
#
#   [15395 rows x 4 columns],
#   'Gyroscope.csv':           Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
#   0       0.030565          -0.015118           0.108578          -0.012904
#   1       0.032951          -0.014431           0.105524          -0.006185
#   2       0.035337          -0.011377           0.106135          -0.003131
#   3       0.037723          -0.012599           0.100637           0.001756
#   4       0.040109          -0.010079           0.098805           0.005421
#   ...          ...                ...                ...                ...
#   15386  36.742071           0.348183          -0.540142           0.163631
#   15387  36.744457           0.328254          -0.532201           0.158133
#   15388  36.746843           0.310769          -0.519984           0.153857
#   15389  36.749229           0.290229          -0.502880           0.144694
#   15390  36.751615           0.272132          -0.480279           0.136753
#
#   [15391 rows x 4 columns],
#   'Linear Acceleration.csv':          Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  \
#   0      0.053224                     0.014899                     0.005713
#   1      0.057996                     0.035059                     0.008970
#   2      0.062768                     0.082035                    -0.026384
#   3      0.067540                     0.000970                    -0.057897
#   4      0.072312                    -0.069308                    -0.088244
#   ...         ...                          ...                          ...
#   7685  36.726553                     0.119707                    -0.369322
#   7686  36.731325                     0.078319                    -0.306282
#   7687  36.736097                     0.081696                    -0.253125
#   7688  36.740869                     0.168371                    -0.237750
#   7689  36.745641                     0.219868                    -0.220771
#
#         Linear_Acceleration_z_m/s^2
#   0                       -0.002448
#   1                       -0.020849
#   2                        0.017530
#   3                        0.013048
#   4                        0.005922
#   ...                           ...
#   7685                     0.737328
#   7686                     0.376156
#   7687                     0.036013
#   7688                    -0.192764
#   7689                    -0.352381
#
#   [7690 rows x 4 columns]},
#  'base_2025-06-07': {'Accelerometer.csv':           Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  \
#   0       0.020304              0.572782              1.105783
#   1       0.022738              0.625424              1.146461
#   2       0.025172              0.615853              1.139283
#   3       0.027605              0.620638              1.156032
#   4       0.030040              0.644567              1.141675
#   ...          ...                   ...                   ...
#   16351  39.024784              2.260619              2.329114
#   16352  39.027169              2.272583              2.264508
#   16353  39.029555              2.241477              2.238187
#   16354  39.031940              2.241477              2.238187
#   16355  39.034325              2.243870              2.221437
#
#          Acceleration_z_m/s^2
#   0                 10.077073
#   1                 10.043574
#   2                 10.031610
#   3                 10.029217
#   4                  9.930812
#   ...                     ...
#   16351              8.616554
#   16352              8.628518
#   16353              8.676374
#   16354              8.736196
#   16355              8.841479
#
#   [16356 rows x 4 columns],
#   'Gyroscope.csv':           Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
#   0       0.102365           0.028023          -0.027335           0.006185
#   1       0.104798           0.029932          -0.031611           0.009239
#   2       0.107231           0.036116          -0.036498           0.012293
#   3       0.109664           0.038025          -0.035887           0.013515
#   4       0.112097           0.038025          -0.036498           0.012293
#   ...          ...                ...                ...                ...
#   16317  39.024254           0.059787          -0.150727           0.031840
#   16318  39.026639           0.037414          -0.106746           0.034284
#   16319  39.029025           0.021227          -0.063375           0.035505
#   16320  39.031410           0.006872          -0.021227           0.037949
#   16321  39.033795          -0.007483           0.017256           0.038560
#
#   [16322 rows x 4 columns],
#   'Linear Acceleration.csv':          Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  \
#   0      0.103596                    -0.056843                    -0.058865
#   1      0.108462                     0.005294                    -0.053916
#   2      0.113328                     0.060203                    -0.109462
#   3      0.118194                     0.113189                    -0.078385
#   4      0.123060                     0.138844                    -0.020647
#   ...         ...                          ...                          ...
#   8156  39.013511                     0.091650                    -0.381640
#   8157  39.018282                     0.116748                    -0.258112
#   8158  39.023052                     0.205232                    -0.123196
#   8159  39.027823                     0.279624                    -0.064267
#   8160  39.032593                     0.285923                    -0.135547
#
#         Linear_Acceleration_z_m/s^2
#   0                        0.229577
#   1                        0.146852
#   2                        0.034380
#   3                       -0.037054
#   4                       -0.080939
#   ...                           ...
#   8156                     0.039774
#   8157                    -0.446812
#   8158                    -0.810875
#   8159                    -0.896005
#   8160                    -0.873350
#
#   [8161 rows x 4 columns]},
#  '85ml_2025-06-13': {'Accelerometer.csv':           Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  \
#   0       0.026486              3.364309              5.204389
#   1       0.028872              3.548556              5.259424
#   2       0.031258              3.694518              5.312366
#   3       0.033644              3.763910              5.353044
#   4       0.036030              3.845565              5.453542
#   ...          ...                   ...                   ...
#   14791  35.316826              2.066501              3.844668
#   14792  35.319212              2.052145              3.887739
#   14793  35.321598              2.049752              3.861418
#   14794  35.323984              2.009074              3.868596
#   14795  35.326370              2.013859              3.875774
#
#          Acceleration_z_m/s^2
#   0                  8.623733
#   1                  8.583055
#   2                  8.585447
#   3                  8.513663
#   4                  8.463413
#   ...                     ...
#   14791              8.408379
#   14792              8.463413
#   14793              8.559127
#   14794              8.628518
#   14795              8.683554
#
#   [14796 rows x 4 columns],
#   'Gyroscope.csv':           Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
#   0       0.076061          -0.651392           1.163511           0.353681
#   1       0.078447          -0.692548           1.198330           0.375671
#   2       0.080833          -0.729275           1.232537           0.401327
#   3       0.083219          -0.750426           1.266744           0.425150
#   4       0.085605          -0.768522           1.297287           0.451416
#   ...          ...                ...                ...                ...
#   14770  35.316296           0.233420           0.077425           0.073913
#   14771  35.318682           0.213415           0.093918           0.075134
#   14772  35.321068           0.198525           0.111021           0.074523
#   14773  35.323454           0.182949           0.125682           0.073302
#   14774  35.325840           0.167372           0.138510           0.072691
#
#   [14775 rows x 4 columns],
#   'Linear Acceleration.csv':          Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  \
#   0      0.098719                     0.000000                     0.000000
#   1      0.103491                     0.412625                     0.314383
#   2      0.108263                     0.618231                     0.319042
#   3      0.113035                     0.682245                     0.269568
#   4      0.117807                     0.579360                     0.324594
#   ...         ...                          ...                          ...
#   7377  35.300779                     0.291855                    -0.153562
#   7378  35.305551                     0.295444                    -0.181644
#   7379  35.310323                     0.300761                    -0.202298
#   7380  35.315094                     0.274319                    -0.193876
#   7381  35.319866                     0.225496                    -0.202978
#
#         Linear_Acceleration_z_m/s^2
#   0                        0.000000
#   1                        0.072441
#   2                        0.082542
#   3                        0.101057
#   4                        0.111126
#   ...                           ...
#   7377                    -0.198435
#   7378                    -0.539962
#   7379                    -0.689548
#   7380                    -0.658263
#   7381                    -0.530008
#
#   [7382 rows x 4 columns]},
#  'base_2025-06-08': {'Accelerometer.csv':           Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  \
#   0       0.021999              1.925325              0.919143
#   1       0.024385              2.056930              0.995713
#   2       0.026771              1.994717              1.041177
#   3       0.029157              1.884647              1.182353
#   4       0.031543              1.602294              1.242174
#   ...          ...                   ...                   ...
#   18092  43.187799              0.773779              2.175973
#   18093  43.190184              0.780958              2.135295
#   18094  43.192570              0.795314              2.113760
#   18095  43.194956              0.795314              2.118545
#   18096  43.197342              0.802493              2.085046
#
#          Acceleration_z_m/s^2
#   0                 10.328320
#   1                 10.440783
#   2                 10.464711
#   3                 10.599008
#   4                 10.706685
#   ...                     ...
#   18092              9.605389
#   18093              9.813564
#   18094              9.988539
#   18095             10.146465
#   18096             10.249356
#
#   [18097 rows x 4 columns],
#   'Gyroscope.csv':           Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
#   0       0.033398          -0.207077           0.420645          -0.173786
#   1       0.035784          -0.197685           0.374831          -0.181116
#   2       0.038170          -0.187759           0.333904          -0.184170
#   3       0.040556          -0.176535           0.297864          -0.189057
#   4       0.042942          -0.167143           0.239834          -0.193944
#   ...          ...                ...                ...                ...
#   18087  43.187269          -0.000840           0.327185           0.140189
#   18088  43.189654           0.006643           0.324131           0.138968
#   18089  43.192040           0.014737           0.307638           0.138357
#   18090  43.194426           0.027259           0.285037           0.134081
#   18091  43.196812           0.040927           0.258159           0.129805
#
#   [18092 rows x 4 columns],
#   'Linear Acceleration.csv':          Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  \
#   0      0.053670                     0.000000                     0.000000
#   1      0.058442                    -0.093346                     0.016243
#   2      0.063214                    -0.165996                     0.011038
#   3      0.067985                    -0.160085                     0.025164
#   4      0.072757                    -0.020687                     0.055738
#   ...         ...                          ...                          ...
#   9036  43.171751                    -0.225208                     0.225694
#   9037  43.176523                    -0.239751                     0.237618
#   9038  43.181295                    -0.278615                     0.292465
#   9039  43.186067                    -0.276505                     0.308369
#   9040  43.190838                    -0.241338                     0.244804
#
#         Linear_Acceleration_z_m/s^2
#   0                        0.000000
#   1                       -0.127625
#   2                       -0.240023
#   3                       -0.295016
#   4                       -0.405553
#   ...                           ...
#   9036                    -0.260992
#   9037                    -0.602212
#   9038                    -0.630319
#   9039                    -0.362149
#   9040                     0.033780
#
#   [9041 rows x 4 columns]},
#  'base_2025-06-10': {'Accelerometer.csv':           Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  \
#   0       0.031504             -0.013759              2.331506
#   1       0.033891              0.046062              2.381756
#   2       0.036278              0.089133              2.381756
#   3       0.038666              0.086740              2.396113
#   4       0.041053              0.086740              2.453541
#   ...          ...                   ...                   ...
#   13781  32.905797              2.188834              2.908476
#   13782  32.908182              2.184049              2.867798
#   13783  32.910568              2.174478              2.855834
#   13784  32.912953              2.176870              2.851048
#   13785  32.915339              2.114657              2.877369
#
#          Acceleration_z_m/s^2
#   0                 10.172787
#   1                 10.225429
#   2                 10.261321
#   3                 10.282856
#   4                 10.311570
#   ...                     ...
#   13781              9.313165
#   13782              9.320343
#   13783              9.375379
#   13784              9.399306
#   13785              9.416057
#
#   [13786 rows x 4 columns],
#   'Gyroscope.csv':           Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
#   0       0.109813          -0.329934           0.228686          -0.144771
#   1       0.112198          -0.314968           0.188370          -0.168594
#   2       0.114584          -0.301835           0.151719          -0.194860
#   3       0.116969          -0.293130           0.120566          -0.215629
#   4       0.119354          -0.287556           0.102241          -0.240063
#   ...          ...                ...                ...                ...
#   13748  32.905267           0.037109           0.124231           0.156377
#   13749  32.907652           0.030237           0.139502           0.151490
#   13750  32.910038           0.027106           0.155995           0.144771
#   13751  32.912423           0.031459           0.165769           0.138051
#   13752  32.914809           0.030848           0.175542           0.133165
#
#   [13753 rows x 4 columns],
#   'Linear Acceleration.csv':          Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  \
#   0      0.108611                     0.733973                     0.425267
#   1      0.113382                     0.579358                     0.437963
#   2      0.118153                     0.484223                     0.539038
#   3      0.122924                     0.382537                     0.530545
#   4      0.127695                     0.252624                     0.439674
#   ...         ...                          ...                          ...
#   6871  32.889752                     0.227468                    -0.132417
#   6872  32.894523                     0.153993                    -0.040172
#   6873  32.899294                     0.168206                    -0.129678
#   6874  32.904065                     0.228230                    -0.170497
#   6875  32.908836                     0.281376                    -0.176192
#
#         Linear_Acceleration_z_m/s^2
#   0                        0.798477
#   1                        0.565559
#   2                        0.372924
#   3                        0.250033
#   4                        0.256452
#   ...                           ...
#   6871                     0.110241
#   6872                    -0.058835
#   6873                    -0.083770
#   6874                    -0.065009
#   6875                    -0.022812
#
#   [6876 rows x 4 columns]},
#  '230ml_2025-06-06': {'Accelerometer.csv':           Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  \
#   0       0.025827              0.771386              0.466600
#   1       0.028261              0.668495              0.457029
#   2       0.030695              0.579960              0.370888
#   3       0.033130              0.570389              0.284746
#   4       0.035564              0.570389              0.224626
#   ...          ...                   ...                   ...
#   14826  35.392622              1.642972              3.356233
#   14827  35.395008              1.698007              3.308376
#   14828  35.397393              1.741078              3.296412
#   14829  35.399779              1.796113              3.337090
#   14830  35.402164              1.867897              3.377768
#
#          Acceleration_z_m/s^2
#   0                 10.447961
#   1                 10.505388
#   2                 10.534102
#   3                 10.551151
#   4                 10.517353
#   ...                     ...
#   14826              8.827123
#   14827              8.831908
#   14828              8.843872
#   14829              8.884850
#   14830              8.884850
#
#   [14831 rows x 4 columns],
#   'Gyroscope.csv':           Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
#   0       0.092414          -0.084908          -0.428509          -0.104760
#   1       0.094800          -0.104226          -0.397967          -0.104149
#   2       0.097185          -0.127896          -0.360018          -0.101706
#   3       0.099571          -0.151566          -0.316648          -0.099874
#   4       0.101956          -0.172183          -0.272056          -0.098041
#   ...          ...                ...                ...                ...
#   14798  35.392092           0.148130          -0.008170           0.160958
#   14799  35.394478           0.128812           0.026648           0.164012
#   14800  35.396863           0.111327           0.054747           0.167067
#   14801  35.399249           0.093918           0.087122           0.168288
#   14802  35.401634           0.078952           0.113389           0.165234
#
#   [14803 rows x 4 columns],
#   'Linear Acceleration.csv':          Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  \
#   0      0.093598                    -0.429390                    -0.012210
#   1      0.098369                    -0.355073                     0.082857
#   2      0.103140                    -0.315672                     0.210070
#   3      0.107911                    -0.264684                     0.246689
#   4      0.112681                    -0.183679                     0.184001
#   ...         ...                          ...                          ...
#   7396  35.378963                     0.058821                    -0.376608
#   7397  35.383734                    -0.064471                    -0.108768
#   7398  35.388505                    -0.090332                    -0.065701
#   7399  35.393276                    -0.009984                    -0.174391
#   7400  35.398047                     0.087723                    -0.229527
#
#         Linear_Acceleration_z_m/s^2
#   0                       -0.231919
#   1                       -0.619518
#   2                       -0.769521
#   3                       -0.739242
#   4                       -0.530979
#   ...                           ...
#   7396                     0.007100
#   7397                    -0.344557
#   7398                    -0.280139
#   7399                    -0.362219
#   7400                    -0.356847
#
#   [7401 rows x 4 columns]},
#  '230ml_2025-06-10': {'Accelerometer.csv':           Time_s  Acceleration_x_m/s^2  Acceleration_y_m/s^2  \
#   0       0.028741             -0.780060              1.780858
#   1       0.031177             -0.784846              1.795215
#   2       0.033613             -0.789631              1.811965
#   3       0.036049             -0.775275              1.883750
#   4       0.038484             -0.736989              1.890928
#   ...          ...                   ...                   ...
#   15905  37.973714              1.264607              1.646860
#   15906  37.976100              1.228714              1.663610
#   15907  37.978485              1.192822              1.749752
#   15908  37.980871              1.109073              1.811965
#   15909  37.983256              1.068395              1.845464
#
#          Acceleration_z_m/s^2
#   0                 10.019646
#   1                 10.101002
#   2                 10.158429
#   3                 10.239785
#   4                 10.323534
#   ...                     ...
#   15905              9.677173
#   15906              9.416057
#   15907              9.207881
#   15908              9.064311
#   15909              9.002098
#
#   [15910 rows x 4 columns],
#   'Gyroscope.csv':           Time_s  Gyroscope_x_rad/s  Gyroscope_y_rad/s  Gyroscope_z_rad/s
#   0       0.120533          -0.108731          -0.306416          -0.109953
#   1       0.122966          -0.109953          -0.311914          -0.109953
#   2       0.125400          -0.119955          -0.312525          -0.106898
#   3       0.127819          -0.136753          -0.301529          -0.105677
#   4       0.130205          -0.160424          -0.272209          -0.104455
#   ...          ...                ...                ...                ...
#   15867  37.973184           0.176077          -0.157980           0.048257
#   15868  37.975570           0.172335          -0.121940           0.040927
#   15869  37.977955           0.161111          -0.076738           0.038483
#   15870  37.980341           0.146756          -0.023594           0.038483
#   15871  37.982726           0.127438           0.033215           0.038483
#
#   [15872 rows x 4 columns],
#   'Linear Acceleration.csv':          Time_s  Linear_Acceleration_x_m/s^2  Linear_Acceleration_y_m/s^2  \
#   0      0.121764                     0.194096                     0.013138
#   1      0.126617                     0.225344                     0.071457
#   2      0.131389                     0.286775                     0.169831
#   3      0.136160                     0.359649                     0.200400
#   4      0.140931                     0.440862                     0.224019
#   ...         ...                          ...                          ...
#   7931  37.962440                     0.594831                     0.292114
#   7932  37.967211                     0.651916                     0.202053
#   7933  37.971982                     0.777677                     0.083668
#   7934  37.976753                     0.915192                     0.016008
#   7935  37.981525                     0.868545                     0.068184
#
#         Linear_Acceleration_z_m/s^2
#   0                        0.358062
#   1                        0.294611
#   2                        0.033933
#   3                       -0.276217
#   4                       -0.490007
#   ...                           ...
#   7931                     1.267894
#   7932                     1.037077
#   7933                     0.609392
#   7934                    -0.049862
#   7935                    -0.556850
#
#   [7936 rows x 4 columns]}}

# %%
def print_keys_recursively(data, indent: int = 0):
    """
    Recursively prints all dict keys and list indices in `data`.
    """
    spacer = "    " * indent
    if isinstance(data, dict):
        for key, value in data.items():
            print(f"{spacer}{key}")
            print_keys_recursively(value, indent + 1)
    elif isinstance(data, list):
        for idx, item in enumerate(data):
            print(f"{spacer}[{idx}]")
            print_keys_recursively(item, indent + 1)
    # you can add more type checks here if needed (e.g. for custom containers)

# Then just call it on your analyzer’s data:
print_keys_recursively(analyzer.all_data)
# Out:
# base_2025-06-11
#     Accelerometer.csv
#     Gyroscope.csv
#     Linear Acceleration.csv
# 200ml_2025-06-07
#     Accelerometer.csv
#     Gyroscope.csv
#     Linear Acceleration.csv
# 230ml_2025-06-09
#     Accelerometer.csv
#     Gyroscope.csv
#     Linear Acceleration.csv
# base_2025-06-09
#     Accelerometer.csv
#     Gyroscope.csv
#     Linear Acceleration.csv
# 150ml_2025-06-12
#     Accelerometer.csv
#     Gyroscope.csv
#     Linear Acceleration.csv
# 230ml_2025-06-11
#     Accelerometer.csv
#     Gyroscope.csv
#     Linear Acceleration.csv
# base_2025-06-13
#     Accelerometer.csv
#     Gyroscope.csv
#     Linear Acceleration.csv
# base_2025-06-06
#     Accelerometer.csv
#     Gyroscope.csv
#     Linear Acceleration.csv
# 470ml_2025-06-08
#     Accelerometer.csv
#     Gyroscope.csv
#     Linear Acceleration.csv
# base_2025-06-12
#     Accelerometer.csv
#     Gyroscope.csv
#     Linear Acceleration.csv
# base_2025-06-07
#     Accelerometer.csv
#     Gyroscope.csv
#     Linear Acceleration.csv
# 85ml_2025-06-13
#     Accelerometer.csv
#     Gyroscope.csv
#     Linear Acceleration.csv
# base_2025-06-08
#     Accelerometer.csv
#     Gyroscope.csv
#     Linear Acceleration.csv
# base_2025-06-10
#     Accelerometer.csv
#     Gyroscope.csv
#     Linear Acceleration.csv
# 230ml_2025-06-06
#     Accelerometer.csv
#     Gyroscope.csv
#     Linear Acceleration.csv
# 230ml_2025-06-10
#     Accelerometer.csv
#     Gyroscope.csv
#     Linear Acceleration.csv

# %% [markdown]
# ### Accelerometer data

# %%
import re
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def extract_date(key):
    """Pull the YYYY-MM-DD from the dataset name and convert to datetime."""
    m = re.search(r'(\d{4}-\d{2}-\d{2})', key)
    return datetime.strptime(m.group(1), '%Y-%m-%d') if m else datetime.min

def plot_combined_accelerations(all_data):
    # 1. Build combined DataFrame
    records = []
    for name, data_dict in all_data.items():
        df = data_dict.get('Accelerometer.csv')
        if df is None:
            continue
        tmp = df[['Time_s', 'Acceleration_x_m/s^2', 'Acceleration_y_m/s^2']].copy()
        tmp['dataset'] = name
        records.append(tmp)
    if not records:
        print("No accelerometer data found.")
        return
    combined = pd.concat(records, ignore_index=True)

    # 2. Build a hue_order sorted purely by the embedded date
    available = combined['dataset'].unique()
    hue_order = sorted(available, key=extract_date)

    # 3. Plot settings
    sns.set_theme(style="whitegrid")

    # 4. Accel X
    plt.figure(figsize=(10, 5))
    sns.lineplot(
        data=combined,
        x='Time_s', y='Acceleration_x_m/s^2',
        hue='dataset', hue_order=hue_order,
        linewidth=1
    )
    plt.xlabel('Time (s)')
    plt.ylabel('Acceleration X (m/s²)')
    plt.title('Combined Acceleration X (chronological order)')
    plt.legend(title='Dataset', loc='best')
    plt.tight_layout()
    plt.show()

    # 5. Accel Y
    plt.figure(figsize=(10, 5))
    sns.lineplot(
        data=combined,
        x='Time_s', y='Acceleration_y_m/s^2',
        hue='dataset', hue_order=hue_order,
        linewidth=1
    )
    plt.xlabel('Time (s)')
    plt.ylabel('Acceleration Y (m/s²)')
    plt.title('Combined Acceleration Y (chronological order)')
    plt.legend(title='Dataset', loc='best')
    plt.tight_layout()
    plt.show()

# %%
plot_combined_accelerations(analyzer.all_data)
# Out:
# /Users/shavindra/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/shavindra/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/shavindra/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/shavindra/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
from AccelInteractivePlot import AccelInteractivePlot
plotter = AccelInteractivePlot(analyzer.all_data)
plotter.display()
# Out:
# VBox(children=(Label(value='Select datasets (chronological):'), Checkbox(value=False, description='base_2025-0…
# Output()

# %% [markdown]
# ### Gyrscope data

# %%
import re
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def extract_date(key):
    """Pull the YYYY-MM-DD from the dataset name and convert to datetime."""
    m = re.search(r'(\d{4}-\d{2}-\d{2})', key)
    return datetime.strptime(m.group(1), '%Y-%m-%d') if m else datetime.min

def plot_combined_gyroscope(all_data):
    """
    Plot three figures (Gyro X, Y, Z) for all 'Gyroscope.csv' datasets in all_data,
    in chronological legend order.
    """
    # 1. Build combined DataFrame
    records = []
    for name, data_dict in all_data.items():
        df = data_dict.get('Gyroscope.csv')
        if df is None:
            continue
        tmp = df[['Time_s',
                  'Gyroscope_x_rad/s',
                  'Gyroscope_y_rad/s',
                  'Gyroscope_z_rad/s']].copy()
        tmp['dataset'] = name
        records.append(tmp)
    if not records:
        print("No gyroscope data found.")
        return
    combined = pd.concat(records, ignore_index=True)

    # 2. Determine legend order by embedded date
    available = combined['dataset'].unique()
    hue_order = sorted(available, key=extract_date)

    # 3. Seaborn theme
    sns.set_theme(style="whitegrid")

    # 4. Plot each axis
    for axis_label in ['x', 'y', 'z']:
        col = f'Gyroscope_{axis_label}_rad/s'
        plt.figure(figsize=(10, 5))
        sns.lineplot(
            data=combined,
            x='Time_s', y=col,
            hue='dataset',
            hue_order=hue_order,
            linewidth=1
        )
        plt.xlabel('Time (s)')
        plt.ylabel(f'Gyroscope {axis_label.upper()} (rad/s)')
        plt.title(f'Combined Gyroscope {axis_label.upper()} (chronological order)')
        plt.legend(title='Dataset', loc='best')
        plt.tight_layout()
        plt.show()

# %%
plot_combined_gyroscope(analyzer.all_data)
# Out:
# /Users/shavindra/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/shavindra/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/shavindra/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/shavindra/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/shavindra/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/shavindra/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
from GyroInteractivePlot import GyroInteractivePlot
gyro_plotter = GyroInteractivePlot(analyzer.all_data)
gyro_plotter.display()
# Out:
# VBox(children=(Label(value='Select datasets (chronological):'), Checkbox(value=False, description='base_2025-0…
# Output()

# %% [markdown]
# ## Linear acceleration

# %%
import re
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def extract_date(key):
    """Pull the YYYY-MM-DD from the dataset name and convert to datetime."""
    m = re.search(r'(\d{4}-\d{2}-\d{2})', key)
    return datetime.strptime(m.group(1), '%Y-%m-%d') if m else datetime.min

def plot_combined_linear_accelerations(all_data):
    # 1. Gather all records
    records = []
    for name, data_dict in all_data.items():
        df = data_dict.get('Linear Acceleration.csv')
        if df is None:
            continue

        # select only the linear acceleration columns
        tmp = df[['Time_s',
                  'Linear_Acceleration_x_m/s^2',
                  'Linear_Acceleration_y_m/s^2',
                  'Linear_Acceleration_z_m/s^2']].copy()

        # melt so we can plot x, y, z on the same axes
        tmp = tmp.melt(
            id_vars='Time_s',
            value_vars=[
                'Linear_Acceleration_x_m/s^2',
                'Linear_Acceleration_y_m/s^2',
                'Linear_Acceleration_z_m/s^2'
            ],
            var_name='axis',
            value_name='linear_acceleration'
        )
        tmp['dataset'] = name
        records.append(tmp)

    if not records:
        print("No linear acceleration data found.")
        return

    combined = pd.concat(records, ignore_index=True)

    # 2. Order datasets by date embedded in the name
    hue_order = sorted(combined['dataset'].unique(), key=extract_date)

    # 3. Plot
    sns.set_theme(style="whitegrid")
    plt.figure(figsize=(12, 6))
    sns.lineplot(
        data=combined,
        x='Time_s',
        y='linear_acceleration',
        hue='dataset',
        style='axis',
        hue_order=hue_order,
        linewidth=1
    )
    plt.xlabel('Time (s)')
    plt.ylabel('Linear acceleration (m/s²)')
    plt.title('Combined linear acceleration (X, Y, Z) in chronological order')
    plt.legend(title='Dataset / axis', loc='best')
    plt.tight_layout()
    plt.show()

# %%
plot_combined_accelerations(analyzer.all_data)
# Out:
# /Users/shavindra/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/shavindra/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/shavindra/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/shavindra/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
from LinearAccInteractivePlot import LinearAccInteractivePlot
linearAcc_plotter = LinearAccInteractivePlot(analyzer.all_data)
linearAcc_plotter.display()
# Out:
# VBox(children=(Label(value='Select datasets (chronological):'), Checkbox(value=False, description='base_2025-0…
# Output()
